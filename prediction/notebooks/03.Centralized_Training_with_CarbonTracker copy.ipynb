# %% [markdown]
# ### In this notebook we perform Centralized learning, almost like 02.Individual_Training.
#
# In centralized learning there is an entity that has access to data from all base stations.
# Here, there is no option to filter out any base station.
# In this setting we also measure the energy consumption using the Carbontracker tool.

# %%
import sys
import os

from pathlib import Path

parent = Path(os.path.abspath("")).resolve().parents[0]
if parent not in sys.path:
    sys.path.insert(0, str(parent))

# %%
import random

import numpy as np
import torch

from argparse import Namespace

# %%
from ml.utils.data_utils import read_data, generate_time_lags, time_to_feature, handle_nans, to_Xy, \
    to_torch_dataset, to_timeseries_rep, assign_statistics, \
    to_train_val, scale_features, get_data_by_area, remove_identifiers, get_exogenous_data_by_area, handle_outliers

# %%
from ml.utils.train_utils import train, test

# %%
from ml.models.mlp import MLP
from ml.models.rnn import RNN
from ml.models.lstm import LSTM
from ml.models.gru import GRU
from ml.models.cnn import CNN
from ml.models.rnn_autoencoder import DualAttentionAutoEncoder

# %%
args = Namespace(
    data_path='../dataset/turbine_prediction_selected_features_400turbines.csv', # dataset
    data_path_test=None , # test dataset
    test_size=0.2, # validation size
    targets=['power_output'], # the target columns
    num_lags= 24, # the number of past observations to feed as input

    
    filter_bs=None, # whether to use a single bs for training. It will be changed dynamically
    identifier='GSRN', # the column name that identifies a bs

    nan_constant=0, # the constant to transform nan values
    x_scaler='minmax', # x_scaler
    y_scaler='minmax', # y_scaler
    outlier_detection=None, # whether to perform flooring and capping

    
    criterion='mse', # optimization criterion, mse or l1
    epochs=50, # the number of maximum epochs
    lr=0.001, # learning rate
    optimizer='adam', # the optimizer, it can be sgd or adam
    batch_size=1024, # the batch size to use
    early_stopping=True, # whether to use early stopping
    patience=10, # patience value for the early stopping parameter (if specified)
    max_grad_norm=0.0, # whether to clip grad norm
    reg1=0.0, # l1 regularization
    reg2=0.0, # l2 regularization
    
    plot_history=True, # plot loss history

    cuda=True, # whether to use gpu
    
    seed=0, # reproducibility

    assign_stats=None, # whether to use statistics as exogenous data, ["mean", "median", "std", "variance", "kurtosis", "skew"]
    use_time_features=False # whether to use datetime features
)

# %%
print(f"Script arguments: {args}\n")
# Out:
# Script arguments: Namespace(data_path='../dataset/turbine_prediction_selected_features_400turbines.csv', data_path_test=None, test_size=0.2, targets=['power_output'], num_lags=24, filter_bs=None, identifier='GSRN', nan_constant=0, x_scaler='minmax', y_scaler='minmax', outlier_detection=None, criterion='mse', epochs=50, lr=0.001, optimizer='adam', batch_size=1024, early_stopping=True, patience=10, max_grad_norm=0.0, reg1=0.0, reg2=0.0, plot_history=True, cuda=True, seed=0, assign_stats=None, use_time_features=False)

# %%
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print("the device currently used is", device)
# Out:
# the device currently used is mps

# %%
# Outlier detection specification
if args.outlier_detection is not None:
    outlier_columns = ['rb_down', 'rb_up', 'down', 'up']
    outlier_kwargs = {"ElBorn": (10, 90), "LesCorts": (10, 90), "PobleSec": (5, 95)}
    args.outlier_columns = outlier_columns
    args.outlier_kwargs = outlier_kwargs

# %%
def seed_all():
    # ensure reproducibility
    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    torch.cuda.manual_seed_all(args.seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
seed_all()

# %% [markdown]
# ### By setting filter_bs to None, the preprocessing pipeline returns data from all three base stations

# %%
def make_preprocessing(filter_bs=None):
    """Preprocess a given .csv"""
    # read data
    df = read_data(args.data_path, filter_data=filter_bs)
    
    # handle nans
    df = handle_nans(train_data=df, constant=args.nan_constant,
                     identifier=args.identifier)
    # split to train/validation
    train_data, val_data = to_train_val(df)
    
    # handle outliers (if specified)
    if args.outlier_detection is not None:
        train_data = handle_outliers(df=train_data, columns=args.outlier_columns,
                                     identifier=args.identifier, kwargs=args.outlier_kwargs)
    
    # get X and y
    X_train, X_val, y_train, y_val = to_Xy(train_data=train_data, val_data=val_data,
                                          targets=args.targets)
    
    # drop cluster columns from X
    if "cluster" in X_train.columns:
        X_train = X_train.drop(columns=["cluster"])
    if "cluster" in X_val.columns:
        X_val = X_val.drop(columns=["cluster"])
    
    # scale X
    X_train, X_val, x_scaler = scale_features(train_data=X_train, val_data=X_val,
                                             scaler=args.x_scaler, identifier=args.identifier)
    # scale y
    y_train, y_val, y_scaler = scale_features(train_data=y_train, val_data=y_val,
                                             scaler=args.y_scaler, identifier=args.identifier)
    
    # generate time lags
    X_train = generate_time_lags(X_train, args.num_lags)
    X_val = generate_time_lags(X_val, args.num_lags)
    y_train = generate_time_lags(y_train, args.num_lags, is_y=True)
    y_val = generate_time_lags(y_val, args.num_lags, is_y=True)
    
    # get datetime features as exogenous data
    date_time_df_train = time_to_feature(
        X_train, args.use_time_features, identifier=args.identifier
    )
    date_time_df_val = time_to_feature(
        X_val, args.use_time_features, identifier=args.identifier
    )
    
    # get statistics as exogenous data
    stats_df_train = assign_statistics(X_train, args.assign_stats, args.num_lags,
                                       targets=args.targets, identifier=args.identifier)
    stats_df_val = assign_statistics(X_val, args.assign_stats, args.num_lags, 
                                       targets=args.targets, identifier=args.identifier)
    
    # concat the exogenous features (if any) to a single dataframe
    if date_time_df_train is not None or stats_df_train is not None:
        exogenous_data_train = pd.concat([date_time_df_train, stats_df_train], axis=1)
        # remove duplicate columns (if any)
        exogenous_data_train = exogenous_data_train.loc[:, ~exogenous_data_train.columns.duplicated()].copy()
        assert len(exogenous_data_train) == len(X_train) == len(y_train)
    else:
        exogenous_data_train = None
    if date_time_df_val is not None or stats_df_val is not None:
        exogenous_data_val = pd.concat([date_time_df_val, stats_df_val], axis=1)
        exogenous_data_val = exogenous_data_val.loc[:, ~exogenous_data_val.columns.duplicated()].copy()
        assert len(exogenous_data_val) == len(X_val) == len(y_val)
    else:
        exogenous_data_val = None
        
    return X_train, X_val, y_train, y_val, exogenous_data_train, exogenous_data_val, x_scaler, y_scaler

# %%
X_train, X_val, y_train, y_val, exogenous_data_train, exogenous_data_val, x_scaler, y_scaler = make_preprocessing()
# Out:
# /Users/libowen/Library/Python/3.10/lib/python/site-packages/sklearn/impute/_base.py:590: FutureWarning: Currently, when `keep_empty_feature=False` and `strategy="constant"`, empty features are not dropped. This behaviour will change in version 1.8. Set `keep_empty_feature=True` to preserve this behaviour.
#   warnings.warn(
# INFO logger 2025-11-17 00:31:59,935 | data_utils.py:393 | Observations info in 571313174116253585
# INFO logger 2025-11-17 00:31:59,936 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:31:59,936 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:31:59,937 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:31:59,939 | data_utils.py:393 | Observations info in 570714700000106958
# INFO logger 2025-11-17 00:31:59,939 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:31:59,940 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:31:59,940 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:31:59,942 | data_utils.py:393 | Observations info in 570714700000004575
# INFO logger 2025-11-17 00:31:59,942 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:31:59,942 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:31:59,942 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:31:59,944 | data_utils.py:393 | Observations info in 570714700000004605
# INFO logger 2025-11-17 00:31:59,944 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:31:59,945 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:31:59,945 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:31:59,947 | data_utils.py:393 | Observations info in 570714700000004568
# INFO logger 2025-11-17 00:31:59,947 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:31:59,947 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:31:59,948 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:31:59,950 | data_utils.py:393 | Observations info in 570714700000005213
# INFO logger 2025-11-17 00:31:59,950 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:31:59,950 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:31:59,950 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:31:59,954 | data_utils.py:393 | Observations info in 570714700000004810
# INFO logger 2025-11-17 00:31:59,955 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:31:59,955 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:31:59,955 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:31:59,957 | data_utils.py:393 | Observations info in 570714700000004964
# INFO logger 2025-11-17 00:31:59,957 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:31:59,957 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:31:59,957 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:31:59,959 | data_utils.py:393 | Observations info in 570714700000004513
# INFO logger 2025-11-17 00:31:59,959 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:31:59,959 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:31:59,960 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:31:59,961 | data_utils.py:393 | Observations info in 570715000000107078
# INFO logger 2025-11-17 00:31:59,961 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:31:59,962 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:31:59,962 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:31:59,964 | data_utils.py:393 | Observations info in 570714700000106699
# INFO logger 2025-11-17 00:31:59,964 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:31:59,964 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:31:59,964 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:31:59,966 | data_utils.py:393 | Observations info in 570714700000106682
# INFO logger 2025-11-17 00:31:59,966 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:31:59,966 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:31:59,966 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:31:59,968 | data_utils.py:393 | Observations info in 570714700000005060
# INFO logger 2025-11-17 00:31:59,968 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:31:59,968 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:31:59,968 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:31:59,970 | data_utils.py:393 | Observations info in 570714700000004476
# INFO logger 2025-11-17 00:31:59,970 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:31:59,970 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:31:59,970 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:31:59,972 | data_utils.py:393 | Observations info in 570714700000004469
# INFO logger 2025-11-17 00:31:59,972 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:31:59,972 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:31:59,972 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:31:59,979 | data_utils.py:393 | Observations info in 570714700000004735
# INFO logger 2025-11-17 00:31:59,988 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:31:59,994 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:31:59,995 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:31:59,999 | data_utils.py:393 | Observations info in 570714700000004742
# INFO logger 2025-11-17 00:32:00,004 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,005 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,006 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,009 | data_utils.py:393 | Observations info in 570714700000004759
# INFO logger 2025-11-17 00:32:00,009 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,009 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,009 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,011 | data_utils.py:393 | Observations info in 570714700000003585
# INFO logger 2025-11-17 00:32:00,014 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,015 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,015 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,018 | data_utils.py:393 | Observations info in 570714700000011825
# INFO logger 2025-11-17 00:32:00,019 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,019 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,020 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,023 | data_utils.py:393 | Observations info in 570714700000011832
# INFO logger 2025-11-17 00:32:00,023 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,023 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,024 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,025 | data_utils.py:393 | Observations info in 570714700000005053
# INFO logger 2025-11-17 00:32:00,025 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,026 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,026 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,027 | data_utils.py:393 | Observations info in 570714700000004520
# INFO logger 2025-11-17 00:32:00,028 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,028 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,028 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,029 | data_utils.py:393 | Observations info in 570714700000010750
# INFO logger 2025-11-17 00:32:00,030 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,030 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,030 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,032 | data_utils.py:393 | Observations info in 570714700000010767
# INFO logger 2025-11-17 00:32:00,032 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,032 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,032 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,034 | data_utils.py:393 | Observations info in 570714700000004728
# INFO logger 2025-11-17 00:32:00,034 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,034 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,035 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,036 | data_utils.py:393 | Observations info in 570714700000004704
# INFO logger 2025-11-17 00:32:00,037 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,037 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,037 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,039 | data_utils.py:393 | Observations info in 570714700000012396
# INFO logger 2025-11-17 00:32:00,039 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,039 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,040 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,041 | data_utils.py:393 | Observations info in 570714700000005039
# INFO logger 2025-11-17 00:32:00,041 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,042 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,042 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,044 | data_utils.py:393 | Observations info in 570714700000009648
# INFO logger 2025-11-17 00:32:00,044 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,044 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,044 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,047 | data_utils.py:393 | Observations info in 570714700000009655
# INFO logger 2025-11-17 00:32:00,047 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,047 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,047 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,049 | data_utils.py:393 | Observations info in 570714700000009945
# INFO logger 2025-11-17 00:32:00,049 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,049 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,049 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,051 | data_utils.py:393 | Observations info in 570714700000009938
# INFO logger 2025-11-17 00:32:00,051 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,051 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,052 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,053 | data_utils.py:393 | Observations info in 570714700000009662
# INFO logger 2025-11-17 00:32:00,054 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,054 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,054 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,056 | data_utils.py:393 | Observations info in 570714700000014284
# INFO logger 2025-11-17 00:32:00,056 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,056 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,056 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,058 | data_utils.py:393 | Observations info in 570714700000014291
# INFO logger 2025-11-17 00:32:00,058 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,058 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,058 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,060 | data_utils.py:393 | Observations info in 570714700000014307
# INFO logger 2025-11-17 00:32:00,060 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,060 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,060 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,062 | data_utils.py:393 | Observations info in 570715000000091681
# INFO logger 2025-11-17 00:32:00,062 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,062 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,062 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,064 | data_utils.py:393 | Observations info in 570714700000010897
# INFO logger 2025-11-17 00:32:00,064 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,064 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,064 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,066 | data_utils.py:393 | Observations info in 570714700000014314
# INFO logger 2025-11-17 00:32:00,066 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,067 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,067 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,068 | data_utils.py:393 | Observations info in 570714700000014321
# INFO logger 2025-11-17 00:32:00,069 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,069 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,069 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,071 | data_utils.py:393 | Observations info in 570714700000005091
# INFO logger 2025-11-17 00:32:00,071 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,071 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,071 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,073 | data_utils.py:393 | Observations info in 570714700000005503
# INFO logger 2025-11-17 00:32:00,073 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,073 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,073 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,075 | data_utils.py:393 | Observations info in 570714700000014338
# INFO logger 2025-11-17 00:32:00,075 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,075 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,075 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,077 | data_utils.py:393 | Observations info in 570714700000004995
# INFO logger 2025-11-17 00:32:00,077 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,077 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,078 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,107 | data_utils.py:393 | Observations info in 570714700000000379
# INFO logger 2025-11-17 00:32:00,107 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,107 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,108 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,109 | data_utils.py:393 | Observations info in 570714700000004940
# INFO logger 2025-11-17 00:32:00,110 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,110 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,110 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,113 | data_utils.py:393 | Observations info in 570715000000128905
# INFO logger 2025-11-17 00:32:00,113 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,118 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,119 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,122 | data_utils.py:393 | Observations info in 570714700000000362
# INFO logger 2025-11-17 00:32:00,122 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,122 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,122 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,125 | data_utils.py:393 | Observations info in 570714700000000355
# INFO logger 2025-11-17 00:32:00,125 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,125 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,125 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,127 | data_utils.py:393 | Observations info in 570714700000000348
# INFO logger 2025-11-17 00:32:00,127 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,127 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,127 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,129 | data_utils.py:393 | Observations info in 570715000000088643
# INFO logger 2025-11-17 00:32:00,129 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,130 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,130 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,131 | data_utils.py:393 | Observations info in 570715000000088667
# INFO logger 2025-11-17 00:32:00,132 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,132 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,132 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,134 | data_utils.py:393 | Observations info in 570714700000000317
# INFO logger 2025-11-17 00:32:00,134 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,134 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,134 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,136 | data_utils.py:393 | Observations info in 570714700000000324
# INFO logger 2025-11-17 00:32:00,137 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,137 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,137 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,138 | data_utils.py:393 | Observations info in 570714700000000140
# INFO logger 2025-11-17 00:32:00,139 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,139 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,139 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,141 | data_utils.py:393 | Observations info in 570714700000000157
# INFO logger 2025-11-17 00:32:00,141 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,141 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,141 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,143 | data_utils.py:393 | Observations info in 570714700000000331
# INFO logger 2025-11-17 00:32:00,143 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,143 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,144 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,145 | data_utils.py:393 | Observations info in 570714700000004384
# INFO logger 2025-11-17 00:32:00,146 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,146 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,146 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,148 | data_utils.py:393 | Observations info in 570714700000008450
# INFO logger 2025-11-17 00:32:00,148 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,148 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,148 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,150 | data_utils.py:393 | Observations info in 570714700000013621
# INFO logger 2025-11-17 00:32:00,150 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,150 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,150 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,152 | data_utils.py:393 | Observations info in 570714700000006258
# INFO logger 2025-11-17 00:32:00,152 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,152 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,153 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,155 | data_utils.py:393 | Observations info in 570714700000012631
# INFO logger 2025-11-17 00:32:00,155 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,155 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,155 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,157 | data_utils.py:393 | Observations info in 570714700000012570
# INFO logger 2025-11-17 00:32:00,157 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,157 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,157 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,159 | data_utils.py:393 | Observations info in 570714700000012648
# INFO logger 2025-11-17 00:32:00,159 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,159 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,160 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,161 | data_utils.py:393 | Observations info in 570714700000013386
# INFO logger 2025-11-17 00:32:00,161 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,161 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,162 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,164 | data_utils.py:393 | Observations info in 570714700000013393
# INFO logger 2025-11-17 00:32:00,164 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,164 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,164 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,166 | data_utils.py:393 | Observations info in 570714700000013409
# INFO logger 2025-11-17 00:32:00,166 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,166 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,167 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,168 | data_utils.py:393 | Observations info in 570714700000012327
# INFO logger 2025-11-17 00:32:00,169 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,169 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,169 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,171 | data_utils.py:393 | Observations info in 570714700000006296
# INFO logger 2025-11-17 00:32:00,171 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,171 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,171 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,173 | data_utils.py:393 | Observations info in 570714700000005138
# INFO logger 2025-11-17 00:32:00,173 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,173 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,173 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,175 | data_utils.py:393 | Observations info in 570714700000005121
# INFO logger 2025-11-17 00:32:00,175 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,175 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,175 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,177 | data_utils.py:393 | Observations info in 570715000000125669
# INFO logger 2025-11-17 00:32:00,178 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,178 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,178 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,180 | data_utils.py:393 | Observations info in 570714700000005114
# INFO logger 2025-11-17 00:32:00,180 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,181 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,181 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,188 | data_utils.py:393 | Observations info in 570714700000005107
# INFO logger 2025-11-17 00:32:00,191 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,191 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,202 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,211 | data_utils.py:393 | Observations info in 570715000000125706
# INFO logger 2025-11-17 00:32:00,211 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,211 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,212 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,213 | data_utils.py:393 | Observations info in 570715000000125652
# INFO logger 2025-11-17 00:32:00,214 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,214 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,214 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,216 | data_utils.py:393 | Observations info in 570714700000008252
# INFO logger 2025-11-17 00:32:00,221 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,221 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,222 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,224 | data_utils.py:393 | Observations info in 570714700000011900
# INFO logger 2025-11-17 00:32:00,224 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,224 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,224 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,226 | data_utils.py:393 | Observations info in 570715000000125683
# INFO logger 2025-11-17 00:32:00,226 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,226 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,226 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,228 | data_utils.py:393 | Observations info in 570715000000125638
# INFO logger 2025-11-17 00:32:00,228 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,229 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,229 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,231 | data_utils.py:393 | Observations info in 570714700000013119
# INFO logger 2025-11-17 00:32:00,231 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,231 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,231 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,233 | data_utils.py:393 | Observations info in 570714700000013188
# INFO logger 2025-11-17 00:32:00,233 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,233 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,233 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,235 | data_utils.py:393 | Observations info in 570714700000013898
# INFO logger 2025-11-17 00:32:00,235 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,235 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,235 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,237 | data_utils.py:393 | Observations info in 570714700000013102
# INFO logger 2025-11-17 00:32:00,237 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,238 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,238 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,239 | data_utils.py:393 | Observations info in 570714700000006029
# INFO logger 2025-11-17 00:32:00,240 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,240 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,240 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,242 | data_utils.py:393 | Observations info in 570714700000013881
# INFO logger 2025-11-17 00:32:00,242 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,242 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,243 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,244 | data_utils.py:393 | Observations info in 570714700000013096
# INFO logger 2025-11-17 00:32:00,244 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,245 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,245 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,247 | data_utils.py:393 | Observations info in 571313161170169709
# INFO logger 2025-11-17 00:32:00,247 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,247 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,247 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,249 | data_utils.py:393 | Observations info in 570714700000003530
# INFO logger 2025-11-17 00:32:00,249 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,249 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,249 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,251 | data_utils.py:393 | Observations info in 571313161170169150
# INFO logger 2025-11-17 00:32:00,251 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,251 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,251 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,253 | data_utils.py:393 | Observations info in 570714700000006289
# INFO logger 2025-11-17 00:32:00,253 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,253 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,254 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,255 | data_utils.py:393 | Observations info in 570714700000013058
# INFO logger 2025-11-17 00:32:00,255 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,256 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,256 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,258 | data_utils.py:393 | Observations info in 570714700000013041
# INFO logger 2025-11-17 00:32:00,258 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,258 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,258 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,260 | data_utils.py:393 | Observations info in 571313161170169785
# INFO logger 2025-11-17 00:32:00,260 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,260 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,260 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,262 | data_utils.py:393 | Observations info in 570714700000012242
# INFO logger 2025-11-17 00:32:00,262 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,262 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,262 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,264 | data_utils.py:393 | Observations info in 570714700000013034
# INFO logger 2025-11-17 00:32:00,264 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,264 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,265 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,267 | data_utils.py:393 | Observations info in 570714700000003523
# INFO logger 2025-11-17 00:32:00,267 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,267 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,267 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,269 | data_utils.py:393 | Observations info in 570714700000003226
# INFO logger 2025-11-17 00:32:00,270 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,270 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,270 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,272 | data_utils.py:393 | Observations info in 570714700000012501
# INFO logger 2025-11-17 00:32:00,272 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,272 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,272 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,274 | data_utils.py:393 | Observations info in 570715000000125621
# INFO logger 2025-11-17 00:32:00,275 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,275 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,275 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,277 | data_utils.py:393 | Observations info in 570714700000010590
# INFO logger 2025-11-17 00:32:00,277 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,277 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,277 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,279 | data_utils.py:393 | Observations info in 570714700000013126
# INFO logger 2025-11-17 00:32:00,279 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,280 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,280 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,287 | data_utils.py:393 | Observations info in 570714700000013133
# INFO logger 2025-11-17 00:32:00,295 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,304 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,308 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,310 | data_utils.py:393 | Observations info in 570715000000125614
# INFO logger 2025-11-17 00:32:00,310 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,310 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,311 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,313 | data_utils.py:393 | Observations info in 571313174001641268
# INFO logger 2025-11-17 00:32:00,317 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,318 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,319 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,322 | data_utils.py:393 | Observations info in 570715000000125591
# INFO logger 2025-11-17 00:32:00,322 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,322 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,322 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,324 | data_utils.py:393 | Observations info in 571313174001641251
# INFO logger 2025-11-17 00:32:00,324 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,324 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,325 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,327 | data_utils.py:393 | Observations info in 570715000000125546
# INFO logger 2025-11-17 00:32:00,327 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,327 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,327 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,329 | data_utils.py:393 | Observations info in 571313174001641244
# INFO logger 2025-11-17 00:32:00,329 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,329 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,329 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,331 | data_utils.py:393 | Observations info in 570715000000125539
# INFO logger 2025-11-17 00:32:00,331 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,331 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,331 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,334 | data_utils.py:393 | Observations info in 570714700000013379
# INFO logger 2025-11-17 00:32:00,334 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,334 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,334 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,336 | data_utils.py:393 | Observations info in 570714700000013362
# INFO logger 2025-11-17 00:32:00,336 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,336 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,337 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,338 | data_utils.py:393 | Observations info in 571313174001641237
# INFO logger 2025-11-17 00:32:00,339 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,339 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,339 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,341 | data_utils.py:393 | Observations info in 570714700000005886
# INFO logger 2025-11-17 00:32:00,341 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,341 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,342 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,344 | data_utils.py:393 | Observations info in 570714700000013355
# INFO logger 2025-11-17 00:32:00,344 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,344 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,344 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,346 | data_utils.py:393 | Observations info in 570714700000012525
# INFO logger 2025-11-17 00:32:00,346 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,346 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,346 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,348 | data_utils.py:393 | Observations info in 570714700000013515
# INFO logger 2025-11-17 00:32:00,349 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,349 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,349 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,351 | data_utils.py:393 | Observations info in 571313174001641220
# INFO logger 2025-11-17 00:32:00,351 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,351 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,351 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,353 | data_utils.py:393 | Observations info in 570714700000003219
# INFO logger 2025-11-17 00:32:00,354 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,354 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,354 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,356 | data_utils.py:393 | Observations info in 570714700000012372
# INFO logger 2025-11-17 00:32:00,356 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,356 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,356 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,358 | data_utils.py:393 | Observations info in 570715000000084652
# INFO logger 2025-11-17 00:32:00,358 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,358 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,358 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,360 | data_utils.py:393 | Observations info in 570714700000013638
# INFO logger 2025-11-17 00:32:00,360 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,361 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,361 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,363 | data_utils.py:393 | Observations info in 570714700000012389
# INFO logger 2025-11-17 00:32:00,363 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:00,363 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:00,363 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:00,365 | data_utils.py:393 | Observations info in 571313174000780944
# ...
# INFO logger 2025-11-17 00:32:01,424 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,424 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,424 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,427 | data_utils.py:393 | Observations info in 570714700000008016
# INFO logger 2025-11-17 00:32:01,427 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,427 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,427 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,429 | data_utils.py:393 | Observations info in 570714700000005978
# INFO logger 2025-11-17 00:32:01,429 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,430 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,430 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,445 | data_utils.py:393 | Observations info in 570714700000005961
# INFO logger 2025-11-17 00:32:01,452 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,456 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,458 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,460 | data_utils.py:393 | Observations info in 570714700000002168
# INFO logger 2025-11-17 00:32:01,460 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,461 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,461 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,463 | data_utils.py:393 | Observations info in 570714700000002175
# INFO logger 2025-11-17 00:32:01,465 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,466 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,469 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,471 | data_utils.py:393 | Observations info in 570714700000008757
# INFO logger 2025-11-17 00:32:01,472 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,472 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,472 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,474 | data_utils.py:393 | Observations info in 570714700000002151
# INFO logger 2025-11-17 00:32:01,474 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,474 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,475 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,476 | data_utils.py:393 | Observations info in 570714700000002205
# INFO logger 2025-11-17 00:32:01,477 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,477 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,477 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,479 | data_utils.py:393 | Observations info in 570714700000002199
# INFO logger 2025-11-17 00:32:01,479 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,480 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,480 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,482 | data_utils.py:393 | Observations info in 570714700000002182
# INFO logger 2025-11-17 00:32:01,482 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,482 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,482 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,484 | data_utils.py:393 | Observations info in 570714700000012853
# INFO logger 2025-11-17 00:32:01,484 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,484 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,485 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,486 | data_utils.py:393 | Observations info in 570714700000012860
# INFO logger 2025-11-17 00:32:01,487 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,487 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,487 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,489 | data_utils.py:393 | Observations info in 570714700000013676
# INFO logger 2025-11-17 00:32:01,489 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,489 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,490 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,491 | data_utils.py:393 | Observations info in 570714700000012884
# INFO logger 2025-11-17 00:32:01,492 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,492 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,492 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,494 | data_utils.py:393 | Observations info in 570714700000012877
# INFO logger 2025-11-17 00:32:01,494 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,494 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,495 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,497 | data_utils.py:393 | Observations info in 570714700000013669
# INFO logger 2025-11-17 00:32:01,497 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,497 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,497 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,499 | data_utils.py:393 | Observations info in 570714700000009419
# INFO logger 2025-11-17 00:32:01,499 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,583 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,584 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,586 | data_utils.py:393 | Observations info in 570714700000010811
# INFO logger 2025-11-17 00:32:01,587 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,587 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,587 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,589 | data_utils.py:393 | Observations info in 570714700000010804
# INFO logger 2025-11-17 00:32:01,589 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,589 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,590 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,591 | data_utils.py:393 | Observations info in 570714700000010774
# INFO logger 2025-11-17 00:32:01,592 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,592 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,592 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,594 | data_utils.py:393 | Observations info in 570715000000089336
# INFO logger 2025-11-17 00:32:01,594 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,594 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,594 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,596 | data_utils.py:393 | Observations info in 570715000000088827
# INFO logger 2025-11-17 00:32:01,596 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,596 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,596 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,599 | data_utils.py:393 | Observations info in 570714700000006890
# INFO logger 2025-11-17 00:32:01,599 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,599 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,599 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,601 | data_utils.py:393 | Observations info in 570714700000003424
# INFO logger 2025-11-17 00:32:01,601 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,601 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,601 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,603 | data_utils.py:393 | Observations info in 570714700000012785
# INFO logger 2025-11-17 00:32:01,603 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,604 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,604 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,606 | data_utils.py:393 | Observations info in 570714700000012778
# INFO logger 2025-11-17 00:32:01,606 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,606 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,606 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,608 | data_utils.py:393 | Observations info in 570714700000009426
# INFO logger 2025-11-17 00:32:01,609 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,609 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,609 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,611 | data_utils.py:393 | Observations info in 570714700000009808
# INFO logger 2025-11-17 00:32:01,611 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,611 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,611 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,613 | data_utils.py:393 | Observations info in 570714700000011207
# INFO logger 2025-11-17 00:32:01,614 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,614 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,614 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,616 | data_utils.py:393 | Observations info in 570714700000002854
# INFO logger 2025-11-17 00:32:01,616 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,616 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,616 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,618 | data_utils.py:393 | Observations info in 570714700000011214
# INFO logger 2025-11-17 00:32:01,619 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,619 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,619 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,630 | data_utils.py:393 | Observations info in 570714700000008702
# INFO logger 2025-11-17 00:32:01,646 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,646 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,646 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,649 | data_utils.py:393 | Observations info in 570714700000007637
# INFO logger 2025-11-17 00:32:01,649 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,649 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,649 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,651 | data_utils.py:393 | Observations info in 570714700000008955
# INFO logger 2025-11-17 00:32:01,653 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,654 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,656 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,660 | data_utils.py:393 | Observations info in 570714700000006876
# INFO logger 2025-11-17 00:32:01,660 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,660 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,660 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,662 | data_utils.py:393 | Observations info in 570714700000009037
# INFO logger 2025-11-17 00:32:01,662 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,663 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,663 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,665 | data_utils.py:393 | Observations info in 570714700000007934
# INFO logger 2025-11-17 00:32:01,665 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,665 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,665 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,667 | data_utils.py:393 | Observations info in 570714700000010163
# INFO logger 2025-11-17 00:32:01,667 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,667 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,668 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,670 | data_utils.py:393 | Observations info in 570714700000002090
# INFO logger 2025-11-17 00:32:01,670 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,670 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,671 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,672 | data_utils.py:393 | Observations info in 570714700000010170
# INFO logger 2025-11-17 00:32:01,672 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-17 00:32:01,673 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-17 00:32:01,673 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-17 00:32:01,722 | data_utils.py:399 | Observations info using all data
# INFO logger 2025-11-17 00:32:01,722 | data_utils.py:400 | 	Total number of samples:  3504000
# INFO logger 2025-11-17 00:32:01,723 | data_utils.py:401 | 	Number of samples for training: 2803200
# INFO logger 2025-11-17 00:32:01,723 | data_utils.py:402 | 	Number of samples for validation:  700800

# %%
X_train.head()
# Out:
#                      Capacity_kw_lag-24  power_output_lag-24  age_lag-24  \
# time
# 2019-01-02 00:00:00            0.230769             0.163281    0.052632
# 2019-01-02 01:00:00            0.230769             0.174871    0.052632
# 2019-01-02 02:00:00            0.230769             0.209959    0.052632
# 2019-01-02 03:00:00            0.230769             0.208609    0.052632
# 2019-01-02 04:00:00            0.230769             0.213543    0.052632
#
#                      wind_dir_cos_lag-24  wind_dir_sin_lag-24  \
# time
# 2019-01-02 00:00:00               0.3875              0.01280
# 2019-01-02 01:00:00               0.3622              0.01935
# 2019-01-02 02:00:00               0.3372              0.02725
# 2019-01-02 03:00:00               0.3290              0.03015
# 2019-01-02 04:00:00               0.3538              0.02185
#
#                      hour_cos_lag-24  hour_sin_lag-24  temperature_c_lag-24  \
# time
# 2019-01-02 00:00:00          1.00000          0.50000              0.318182
# 2019-01-02 01:00:00          0.98295          0.62940              0.318182
# 2019-01-02 02:00:00          0.93300          0.75000              0.318182
# 2019-01-02 03:00:00          0.85355          0.85355              0.318182
# 2019-01-02 04:00:00          0.75000          0.93300              0.328877
#
#                      wind_speed_lag-24  Capacity_kw_lag-23  ...  \
# time                                                        ...
# 2019-01-02 00:00:00           0.525490            0.230769  ...
# 2019-01-02 01:00:00           0.564706            0.230769  ...
# 2019-01-02 02:00:00           0.564706            0.230769  ...
# 2019-01-02 03:00:00           0.572549            0.230769  ...
# 2019-01-02 04:00:00           0.623529            0.230769  ...
#
#                      Capacity_kw_lag-1  power_output_lag-1  age_lag-1  \
# time
# 2019-01-02 00:00:00           0.230769            0.221352   0.052632
# 2019-01-02 01:00:00           0.230769            0.221129   0.052632
# 2019-01-02 02:00:00           0.230769            0.221195   0.052632
# 2019-01-02 03:00:00           0.230769            0.221206   0.052632
# 2019-01-02 04:00:00           0.230769            0.221263   0.052632
#
#                      wind_dir_cos_lag-1  wind_dir_sin_lag-1  hour_cos_lag-1  \
# time
# 2019-01-02 00:00:00             0.98065             0.36220         0.98295
# 2019-01-02 01:00:00             0.98905             0.39605         1.00000
# 2019-01-02 02:00:00             0.99385             0.42180         0.98295
# 2019-01-02 03:00:00             0.99725             0.44775         0.93300
# 2019-01-02 04:00:00             0.99880             0.46510         0.85355
#
#                      hour_sin_lag-1  temperature_c_lag-1  wind_speed_lag-1  \
# time
# 2019-01-02 00:00:00         0.37060             0.240642          0.839216
# 2019-01-02 01:00:00         0.50000             0.221925          0.823529
# 2019-01-02 02:00:00         0.62940             0.211230          0.784314
# 2019-01-02 03:00:00         0.75000             0.200535          0.737255
# 2019-01-02 04:00:00         0.85355             0.195187          0.705882
#
#                                    GSRN
# time
# 2019-01-02 00:00:00  571313174116253585
# 2019-01-02 01:00:00  571313174116253585
# 2019-01-02 02:00:00  571313174116253585
# 2019-01-02 03:00:00  571313174116253585
# 2019-01-02 04:00:00  571313174116253585
#
# [5 rows x 217 columns]

# %%
y_train.head()
# Out:
#                      power_output                GSRN
# time
# 2019-01-02 00:00:00      0.221129  571313174116253585
# 2019-01-02 01:00:00      0.221195  571313174116253585
# 2019-01-02 02:00:00      0.221206  571313174116253585
# 2019-01-02 03:00:00      0.221263  571313174116253585
# 2019-01-02 04:00:00      0.221120  571313174116253585

# %%
x_scaler, y_scaler
# Out:
# (MinMaxScaler(), MinMaxScaler())

# %%
def make_postprocessing(X_train, X_val, y_train, y_val, exogenous_data_train, exogenous_data_val, x_scaler, y_scaler):
    """Make data ready to be fed into ml algorithms"""
    # if there are more than one specified areas, get the data per area
    if X_train[args.identifier].nunique() != 1:
        area_X_train, area_X_val, area_y_train, area_y_val = get_data_by_area(X_train, X_val,
                                                                              y_train, y_val, 
                                                                              identifier=args.identifier)
    else:
        area_X_train, area_X_val, area_y_train, area_y_val = None, None, None, None

    # Get the exogenous data per area.
    if exogenous_data_train is not None:
        exogenous_data_train, exogenous_data_val = get_exogenous_data_by_area(exogenous_data_train,
                                                                              exogenous_data_val)
    # transform to np
    if area_X_train is not None:
        for area in area_X_train:
            tmp_X_train, tmp_y_train, tmp_X_val, tmp_y_val = remove_identifiers(
                area_X_train[area], area_y_train[area], area_X_val[area], area_y_val[area])
            tmp_X_train, tmp_y_train = tmp_X_train.to_numpy(), tmp_y_train.to_numpy()
            tmp_X_val, tmp_y_val = tmp_X_val.to_numpy(), tmp_y_val.to_numpy()
            area_X_train[area] = tmp_X_train
            area_X_val[area] = tmp_X_val
            area_y_train[area] = tmp_y_train
            area_y_val[area] = tmp_y_val
    
    if exogenous_data_train is not None:
        for area in exogenous_data_train:
            exogenous_data_train[area] = exogenous_data_train[area].to_numpy()
            exogenous_data_val[area] = exogenous_data_val[area].to_numpy()
    
    # remove identifiers from features, targets
    X_train, y_train, X_val, y_val = remove_identifiers(X_train, y_train, X_val, y_val)
    assert len(X_train.columns) == len(X_val.columns)
    
    num_features = len(X_train.columns) // args.num_lags
    
    # to timeseries representation
    X_train = to_timeseries_rep(X_train.to_numpy(), num_lags=args.num_lags,
                                            num_features=num_features)
    X_val = to_timeseries_rep(X_val.to_numpy(), num_lags=args.num_lags,
                                          num_features=num_features)
    
    if area_X_train is not None:
        area_X_train = to_timeseries_rep(area_X_train, num_lags=args.num_lags,
                                                     num_features=num_features)
        area_X_val = to_timeseries_rep(area_X_val, num_lags=args.num_lags,
                                                   num_features=num_features)
    
    # transform targets to numpy
    y_train, y_val = y_train.to_numpy(), y_val.to_numpy()
    
    # centralized (all) learning specific
    if not args.filter_bs and exogenous_data_train is not None:
        exogenous_data_train_combined, exogenous_data_val_combined = [], []
        for area in exogenous_data_train:
            exogenous_data_train_combined.extend(exogenous_data_train[area])
            exogenous_data_val_combined.extend(exogenous_data_val[area])
        exogenous_data_train_combined = np.stack(exogenous_data_train_combined)
        exogenous_data_val_combined = np.stack(exogenous_data_val_combined)
        exogenous_data_train["all"] = exogenous_data_train_combined
        exogenous_data_val["all"] = exogenous_data_val_combined
    return X_train, X_val, y_train, y_val, area_X_train, area_X_val, area_y_train, area_y_val, exogenous_data_train, exogenous_data_val

# %%
X_train, X_val, y_train, y_val, area_X_train, area_X_val, area_y_train, area_y_val, exogenous_data_train, exogenous_data_val = make_postprocessing(X_train, X_val, y_train, y_val, exogenous_data_train, exogenous_data_val, x_scaler, y_scaler)

# %%
area_X_train.keys()
# Out:
# dict_keys([np.int64(571313174116253585), np.int64(570714700000106958), np.int64(570714700000004575), np.int64(570714700000004605), np.int64(570714700000004568), np.int64(570714700000005213), np.int64(570714700000004810), np.int64(570714700000004964), np.int64(570714700000004513), np.int64(570715000000107078), np.int64(570714700000106699), np.int64(570714700000106682), np.int64(570714700000005060), np.int64(570714700000004476), np.int64(570714700000004469), np.int64(570714700000004735), np.int64(570714700000004742), np.int64(570714700000004759), np.int64(570714700000003585), np.int64(570714700000011825), np.int64(570714700000011832), np.int64(570714700000005053), np.int64(570714700000004520), np.int64(570714700000010750), np.int64(570714700000010767), np.int64(570714700000004728), np.int64(570714700000004704), np.int
), np.int64(570714700000004759), np.int64(570714700000003585), np.int64(570714700000011825), np.int64(570714700000011832), np.int64(570714700000005053), np.int64(570714700000004520), np.int64(570714700000010750), np.int64(570714700000010767), np.int64(570714700000004728), np.int64(570714700000004704), np.int64(570714700000012396), np.int64(570714700000005039), np.int64(570714700000009648), np.int64(570714700000009655), np.int64(570714700000009945), np.int64(570714700000009938), np.int64(570714700000009662), np.int64(570714700000014284), np.int64(570714700000014291), np.int64(570714700000014307), np.int64(570715000000091681), np.int64(570714700000010897), np.int64(570714700000014314), np.int64(570714700000014321), np.int64(570714700000005091), np.int64(570714700000005503), np.int64(570714700000014338), np.int64(570714700000004995), np.int64(570714700000000379), np.int64(570714700000004940), np.int64(570715000000128905), np.int64(570714700000000362), np.int64(570714700000000355), np.int64(570714700000000348), np.int64(570715000000088643), np.int64(570715000000088667), np.int64(570714700000000317), np.int64(570714700000000324), np.int64(570714700000000140), np.int64(570714700000000157), np.int64(570714700000000331), np.int64(570714700000004384), np.int64(570714700000008450), np.int64(570714700000013621), np.int64(570714700000006258), np.int64(570714700000012631), np.int64(570714700000012570), np.int64(570714700000012648), np.int64(570714700000013386), np.int64(570714700000013393), np.int64(570714700000013409), np.int64(570714700000012327), np.int64(570714700000006296), np.int64(570714700000005138), np.int64(570714700000005121), np.int64(570715000000125669), np.int64(570714700000005114), np.int64(570714700000005107), np.int64(570715000000125706), np.int64(570715000000125652), np.int64(570714700000008252), np.int64(570714700000011900), np.int64(570715000000125683), np.int64(570715000000125638), np.int64(570714700000013119), np.int64(570714700000013188), np.int64(570714700000013898), np.int64(570714700000013102), np.int64(570714700000006029), np.int64(570714700000013881), np.int64(570714700000013096), np.int64(571313161170169709), np.int64(570714700000003530), np.int64(571313161170169150), np.int64(570714700000006289), np.int64(570714700000013058), np.int64(570714700000013041), np.int64(571313161170169785), np.int64(570714700000012242), np.int64(570714700000013034), np.int64(570714700000003523), np.int64(570714700000003226), np.int64(570714700000012501), np.int64(570715000000125621), np.int64(570714700000010590), np.int64(570714700000013126), np.int64(570714700000013133), np.int64(570715000000125614), np.int64(571313174001641268), np.int64(570715000000125591), np.int64(571313174001641251), np.int64(570715000000125546), np.int64(571313174001641244), np.int64(570715000000125539), np.int64(570714700000013379), np.int64(570714700000013362), np.int64(571313174001641237), np.int64(570714700000005886), np.int64(570714700000013355), np.int64(570714700000012525), np.int64(570714700000013515), np.int64(571313174001641220), np.int64(570714700000003219), np.int64(570714700000012372), np.int64(570715000000084652), np.int64(570714700000013638), np.int64(570714700000012389), np.int64(571313174000780944), np.int64(570714700000012419), np.int64(570715000000084607), np.int64(571313174000780951), np.int64(570714700000012402), np.int64(570714700000010989), np.int64(570714700000013348), np.int64(570714700000013331), np.int64(570714700000013324), ...

# %%
X_train[:2]
# Out:
# array([[[[2.30769232e-01],
#          [1.63281038e-01],
#          [5.26315756e-02],
#          [3.87499988e-01],
#          [1.28000081e-02],
#          [1.00000000e+00],
#          [5.00000000e-01],
#          [8.27451050e-01]],
#
#         [[2.30769232e-01],
#          [2.21345767e-01],
#          [5.26315756e-02],
#          [7.03350008e-01],
#          [4.32499945e-02],
#          [1.46450013e-01],
#          [1.46450013e-01],
#          [2.67379671e-01],
#          [7.96078444e-01]],
#
#         [[2.30769232e-01],
#          [2.21359059e-01],
#          [5.26315756e-02],
#          [7.26999998e-01],
#          [5.45000136e-02],
#          [2.50000000e-01],
#          [6.70000017e-02],
#          [2.70053446e-01],
#          [7.33333409e-01]],
#
#         [[2.30769232e-01],
#          [2.21202120e-01],
#          [5.26315756e-02],
#          [7.72300005e-01],
#          [8.06500018e-02],
#          [3.70599985e-01],
#          [1.70499980e-02],
#          [2.67379671e-01],
#          [6.94117725e-01]],
#
#         [[2.30769232e-01],
#          [2.21361443e-01],
#          [5.26315756e-02],
#          [9.04500008e-01],
#          [2.06099987e-01],
#          [5.00000000e-01],
#          [0.00000000e+00],
#          [2.94117630e-01],
#          [7.56862760e-01]],
#
#         [[2.30769232e-01],
#          [2.21381351e-01],
#          [5.26315756e-02],
#          [9.78150010e-01],
#          [3.53799999e-01],
#          [6.29400015e-01],
#          [1.70499980e-02],
#          [2.94117630e-01],
#          [7.72549093e-01]],
#
#         [[2.30769232e-01],
#          [2.21381888e-01],
#          [5.26315756e-02],
#          [9.72750008e-01],
#          [3.37199986e-01],
#          [7.50000000e-01],
#          [6.70000017e-02],
#          [2.83422440e-01],
#          [7.33333409e-01]],
#
#         [[2.30769232e-01],
#          [2.21388519e-01],
#          [5.26315756e-02],
#          [9.72750008e-01],
#          [3.37199986e-01],
#          [8.53549957e-01],
#          [1.46450013e-01],
#          [2.78074861e-01],
#          [7.72549093e-01]],
#
#         [[2.30769232e-01],
#          [2.21243009e-01],
#          [5.26315756e-02],
#          [9.75549996e-01],
#          [3.45499992e-01],
#          [9.32999969e-01],
#          [2.50000000e-01],
#          [2.54010677e-01],
#          [8.39215696e-01]],
#
#         [[2.30769232e-01],
#          [2.21352413e-01],
#          [5.26315756e-02],
#          [9.80650008e-01],
#          [3.62200022e-01],
#          [9.82949972e-01],
#          [3.70599985e-01],
#          [2.40641698e-01],
#          [8.39215696e-01]],
#
#         [[2.30769232e-01],
#          [2.21128836e-01],
#          [5.26315756e-02],
#          [9.89050031e-01],
#          [3.96050006e-01],
#          [1.00000000e+00],
#          [5.00000000e-01],
#          [2.21925125e-01],
#          [8.23529422e-01]]]])

# %%
y_train[:2]
# Out:
# array([[0.22112884],
#        [0.22119494]], dtype=float32)

# %%
len(X_train), len(X_val)
# Out:
# (2793600, 691200)

# %%
def get_input_dims(X_train, exogenous_data_train):
    if args.model_name == "mlp":
        input_dim = X_train.shape[1] * X_train.shape[2]
    else:
        input_dim = X_train.shape[2]
    
    if exogenous_data_train is not None:
        if len(exogenous_data_train) == 1:
            cid = next(iter(exogenous_data_train.keys()))
            exogenous_dim = exogenous_data_train[cid].shape[1]
        else:
            exogenous_dim = exogenous_data_train["all"].shape[1]
    else:
        exogenous_dim = 0
    
    return input_dim, exogenous_dim

# %%
def get_model(model: str,
              input_dim: int,
              out_dim: int,
              lags: int = 10,
              exogenous_dim: int = 0,
              seed=0):
    if model == "mlp":
        model = MLP(input_dim=input_dim, layer_units=[256, 128, 64], num_outputs=out_dim)
    elif model == "rnn":
        model = RNN(input_dim=input_dim, rnn_hidden_size=128, num_rnn_layers=1, rnn_dropout=0.0,
                    layer_units=[128], num_outputs=out_dim, matrix_rep=True, exogenous_dim=exogenous_dim)
    elif model == "lstm":
        model = LSTM(input_dim=input_dim, lstm_hidden_size=128, num_lstm_layers=1, lstm_dropout=0.0,
                     layer_units=[128], num_outputs=out_dim, matrix_rep=True, exogenous_dim=exogenous_dim)
    elif model == "gru":
        model = GRU(input_dim=input_dim, gru_hidden_size=128, num_gru_layers=1, gru_dropout=0.0,
                    layer_units=[128], num_outputs=out_dim, matrix_rep=True, exogenous_dim=exogenous_dim)
    elif model == "cnn":
        model = CNN(num_features=input_dim, lags=lags, exogenous_dim=exogenous_dim, out_dim=out_dim)
    elif model == "da_encoder_decoder":
        model = DualAttentionAutoEncoder(input_dim=input_dim, architecture="lstm", matrix_rep=True)
    else:
        raise NotImplementedError("Specified model is not implemented. Plese define your own model or choose one from ['mlp', 'rnn', 'lstm', 'gru', 'cnn', 'da_encoder_decoder']")
    return model

# %%
# define the model
args.model_name = "lstm"

input_dim, exogenous_dim = get_input_dims(X_train, exogenous_data_train)

print(input_dim, exogenous_dim)

model = get_model(model=args.model_name,
                  input_dim=input_dim,
                  out_dim=y_train.shape[1],
                  lags=args.num_lags,
                  exogenous_dim=exogenous_dim,
                  seed=args.seed)
# Out:
# 9 0

# %%
model
# Out:
# LSTM(
#   (lstm): LSTM(9, 128, batch_first=True)
#   (MLP_layers): Sequential(
#     (0): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
def fit(model, X_train, y_train, X_val, y_val, 
        exogenous_data_train=None, exogenous_data_val=None, 
        idxs=[], # the indices of our targets in X
        log_per=1):
    
    # get exogenous data (if any)
    if exogenous_data_train is not None and len(exogenous_data_train) > 1:
        exogenous_data_train = exogenous_data_train["all"]
        exogenous_data_val = exogenous_data_val["all"]
    elif exogenous_data_train is not None and len(exogenous_data_train) == 1:
        cid = next(iter(exogenous_data_train.keys()))
        exogenous_data_train = exogenous_data_train[cid]
        exogenous_data_val = exogenous_data_val[cid]
    else:
        exogenous_data_train = None
        exogenous_data_val = None
    num_features = len(X_train[0][0])
    
    # to torch loader
    train_loader = to_torch_dataset(X_train, y_train,
                                    num_lags=args.num_lags,
                                    num_features=num_features,
                                    exogenous_data=exogenous_data_train,
                                    indices=idxs,
                                    batch_size=args.batch_size, 
                                    shuffle=False)
    val_loader = to_torch_dataset(X_val, y_val, 
                                  num_lags=args.num_lags,
                                  num_features=num_features,
                                  exogenous_data=exogenous_data_val,
                                  indices=idxs,
                                  batch_size=args.batch_size,
                                  shuffle=False)
    
    # train the model
    model = train(model, 
                  train_loader, val_loader,
                  epochs=args.epochs,
                  optimizer=args.optimizer, lr=args.lr,
                  criterion=args.criterion,
                  early_stopping=args.early_stopping,
                  patience=args.patience,
                  plot_history=args.plot_history, 
                  device=device, log_per=log_per,
                  use_carbontracker=False)
    
    return model

# %%
trained_model = fit(model, X_train, y_train, X_val, y_val)

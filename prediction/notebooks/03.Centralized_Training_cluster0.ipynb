# %% [markdown]
# ### In this notebook we perform Centralized learning, almost like 02.Individual_Training.
#
# In centralized learning there is an entity that has access to data from all base stations.
# Here, there is no option to filter out any base station.
# In this setting we also measure the energy consumption using the Carbontracker tool.

# %%
import sys
import os

from pathlib import Path

parent = Path(os.path.abspath("")).resolve().parents[0]
if parent not in sys.path:
    sys.path.insert(0, str(parent))

# %%
import random

import numpy as np
import torch

from argparse import Namespace

# %%
from ml.utils.data_utils import read_data, generate_time_lags, time_to_feature, handle_nans, to_Xy, \
    to_torch_dataset, to_timeseries_rep, assign_statistics, \
    to_train_val, scale_features, get_data_by_area, remove_identifiers, get_exogenous_data_by_area, handle_outliers

# %%
from ml.utils.train_utils import train, test

# %%
from ml.models.mlp import MLP
from ml.models.rnn import RNN
from ml.models.lstm import LSTM
from ml.models.gru import GRU
from ml.models.cnn import CNN
from ml.models.rnn_autoencoder import DualAttentionAutoEncoder

# %%
args = Namespace(
    data_path='../dataset/cluster_split/cluster_0.csv', # dataset
    data_path_test=None , # test dataset
    test_size=0.2, # validation size
    targets=['power_output'], # the target columns
    num_lags= 24, # the number of past observations to feed as input

    
    filter_bs=None, # whether to use a single bs for training. It will be changed dynamically
    identifier='GSRN', # the column name that identifies a bs

    nan_constant=0, # the constant to transform nan values
    x_scaler='minmax', # x_scaler
    y_scaler='minmax', # y_scaler
    outlier_detection=None, # whether to perform flooring and capping

    
    criterion='mse', # optimization criterion, mse or l1
    epochs=50, # the number of maximum epochs
    lr=0.001, # learning rate
    optimizer='adam', # the optimizer, it can be sgd or adam
    batch_size=1024, # the batch size to use
    early_stopping=True, # whether to use early stopping
    patience=10, # patience value for the early stopping parameter (if specified)
    max_grad_norm=0.0, # whether to clip grad norm
    reg1=0.0, # l1 regularization
    reg2=0.0, # l2 regularization
    
    plot_history=True, # plot loss history

    cuda=True, # whether to use gpu
    
    seed=0, # reproducibility

    assign_stats=None, # whether to use statistics as exogenous data, ["mean", "median", "std", "variance", "kurtosis", "skew"]
    use_time_features=False # whether to use datetime features
)

# %%
print(f"Script arguments: {args}\n")
# Out:
# Script arguments: Namespace(data_path='../dataset/cluster_split/cluster_0.csv', data_path_test=None, test_size=0.2, targets=['power_output'], num_lags=24, filter_bs=None, identifier='GSRN', nan_constant=0, x_scaler='minmax', y_scaler='minmax', outlier_detection=None, criterion='mse', epochs=50, lr=0.001, optimizer='adam', batch_size=1024, early_stopping=True, patience=10, max_grad_norm=0.0, reg1=0.0, reg2=0.0, plot_history=True, cuda=True, seed=0, assign_stats=None, use_time_features=False)

# %%
if torch.backends.mps.is_available():
    device = torch.device("mps")
elif torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

print("the device currently used is", device)
# Out:
# the device currently used is mps

# %%
def seed_all():
    # ensure reproducibility
    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    torch.cuda.manual_seed_all(args.seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# %%
seed_all()

# %% [markdown]
# ### By setting filter_bs to None, the preprocessing pipeline returns data from all three base stations

# %%
def make_preprocessing(filter_bs=None):
    """Preprocess a given .csv"""
    # read data
    df = read_data(args.data_path, filter_data=filter_bs)
    
    # handle nans
    df = handle_nans(train_data=df, constant=args.nan_constant,
                     identifier=args.identifier)
    # split to train/validation
    train_data, val_data = to_train_val(df)
    
    # handle outliers (if specified)
    if args.outlier_detection is not None:
        train_data = handle_outliers(df=train_data, columns=args.outlier_columns,
                                     identifier=args.identifier, kwargs=args.outlier_kwargs)
    
    # get X and y
    X_train, X_val, y_train, y_val = to_Xy(train_data=train_data, val_data=val_data,
                                          targets=args.targets)
    
    # drop cluster columns from X
    if "cluster" in X_train.columns:
        X_train = X_train.drop(columns=["cluster"])
    if "cluster" in X_val.columns:
        X_val = X_val.drop(columns=["cluster"])
    
    # scale X
    X_train, X_val, x_scaler = scale_features(train_data=X_train, val_data=X_val,
                                             scaler=args.x_scaler, identifier=args.identifier)
    # scale y
    y_train, y_val, y_scaler = scale_features(train_data=y_train, val_data=y_val,
                                             scaler=args.y_scaler, identifier=args.identifier)
    
    # generate time lags
    X_train = generate_time_lags(X_train, args.num_lags)
    X_val = generate_time_lags(X_val, args.num_lags)
    y_train = generate_time_lags(y_train, args.num_lags, is_y=True)
    y_val = generate_time_lags(y_val, args.num_lags, is_y=True)
    
    # get datetime features as exogenous data
    date_time_df_train = time_to_feature(
        X_train, args.use_time_features, identifier=args.identifier
    )
    date_time_df_val = time_to_feature(
        X_val, args.use_time_features, identifier=args.identifier
    )
    
    # get statistics as exogenous data
    stats_df_train = assign_statistics(X_train, args.assign_stats, args.num_lags,
                                       targets=args.targets, identifier=args.identifier)
    stats_df_val = assign_statistics(X_val, args.assign_stats, args.num_lags, 
                                       targets=args.targets, identifier=args.identifier)
    
    # concat the exogenous features (if any) to a single dataframe
    if date_time_df_train is not None or stats_df_train is not None:
        exogenous_data_train = pd.concat([date_time_df_train, stats_df_train], axis=1)
        # remove duplicate columns (if any)
        exogenous_data_train = exogenous_data_train.loc[:, ~exogenous_data_train.columns.duplicated()].copy()
        assert len(exogenous_data_train) == len(X_train) == len(y_train)
    else:
        exogenous_data_train = None
    if date_time_df_val is not None or stats_df_val is not None:
        exogenous_data_val = pd.concat([date_time_df_val, stats_df_val], axis=1)
        exogenous_data_val = exogenous_data_val.loc[:, ~exogenous_data_val.columns.duplicated()].copy()
        assert len(exogenous_data_val) == len(X_val) == len(y_val)
    else:
        exogenous_data_val = None
        
    return X_train, X_val, y_train, y_val, exogenous_data_train, exogenous_data_val, x_scaler, y_scaler

# %%
X_train, X_val, y_train, y_val, exogenous_data_train, exogenous_data_val, x_scaler, y_scaler = make_preprocessing()
# Out:
# /Users/libowen/Library/Python/3.10/lib/python/site-packages/sklearn/impute/_base.py:590: FutureWarning: Currently, when `keep_empty_feature=False` and `strategy="constant"`, empty features are not dropped. This behaviour will change in version 1.8. Set `keep_empty_feature=True` to preserve this behaviour.
#   warnings.warn(
# INFO logger 2025-11-16 23:19:30,953 | data_utils.py:393 | Observations info in 570715000000128905
# INFO logger 2025-11-16 23:19:30,953 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,953 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,953 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,956 | data_utils.py:393 | Observations info in 570715000000088643
# INFO logger 2025-11-16 23:19:30,956 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,956 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,956 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,957 | data_utils.py:393 | Observations info in 570715000000088667
# INFO logger 2025-11-16 23:19:30,958 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,958 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,958 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,959 | data_utils.py:393 | Observations info in 570715000000125669
# INFO logger 2025-11-16 23:19:30,960 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,960 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,960 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,961 | data_utils.py:393 | Observations info in 570715000000125706
# INFO logger 2025-11-16 23:19:30,961 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,961 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,961 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,963 | data_utils.py:393 | Observations info in 570715000000125652
# INFO logger 2025-11-16 23:19:30,963 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,963 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,963 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,964 | data_utils.py:393 | Observations info in 570715000000125683
# INFO logger 2025-11-16 23:19:30,965 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,965 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,965 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,966 | data_utils.py:393 | Observations info in 571313161170169709
# INFO logger 2025-11-16 23:19:30,966 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,967 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,967 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,968 | data_utils.py:393 | Observations info in 571313161170169150
# INFO logger 2025-11-16 23:19:30,969 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,969 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,969 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,970 | data_utils.py:393 | Observations info in 571313161170169785
# INFO logger 2025-11-16 23:19:30,971 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,971 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,971 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,973 | data_utils.py:393 | Observations info in 570715000000125621
# INFO logger 2025-11-16 23:19:30,973 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,973 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,973 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,974 | data_utils.py:393 | Observations info in 570715000000125614
# INFO logger 2025-11-16 23:19:30,974 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,974 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,975 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,976 | data_utils.py:393 | Observations info in 571313174001641268
# INFO logger 2025-11-16 23:19:30,976 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,976 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,976 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,977 | data_utils.py:393 | Observations info in 570715000000125591
# INFO logger 2025-11-16 23:19:30,978 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,978 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,978 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,980 | data_utils.py:393 | Observations info in 571313174001641251
# INFO logger 2025-11-16 23:19:30,980 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,980 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,980 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,981 | data_utils.py:393 | Observations info in 570715000000125546
# INFO logger 2025-11-16 23:19:30,981 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,982 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,982 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,983 | data_utils.py:393 | Observations info in 571313174001641244
# INFO logger 2025-11-16 23:19:30,983 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,983 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,983 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,985 | data_utils.py:393 | Observations info in 571313174001641237
# INFO logger 2025-11-16 23:19:30,985 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,986 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,986 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,987 | data_utils.py:393 | Observations info in 571313174001641220
# INFO logger 2025-11-16 23:19:30,987 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,987 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,987 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,988 | data_utils.py:393 | Observations info in 570715000000084652
# INFO logger 2025-11-16 23:19:30,989 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,989 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,989 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,990 | data_utils.py:393 | Observations info in 571313174000780944
# INFO logger 2025-11-16 23:19:30,990 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,990 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,990 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,991 | data_utils.py:393 | Observations info in 570715000000084607
# INFO logger 2025-11-16 23:19:30,991 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,992 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,992 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,994 | data_utils.py:393 | Observations info in 571313174000780951
# INFO logger 2025-11-16 23:19:30,995 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,995 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:30,996 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:30,998 | data_utils.py:393 | Observations info in 571313174000602154
# INFO logger 2025-11-16 23:19:30,999 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:30,999 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,000 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,002 | data_utils.py:393 | Observations info in 571313174000602147
# INFO logger 2025-11-16 23:19:31,003 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,005 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,035 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,037 | data_utils.py:393 | Observations info in 571313174000602130
# INFO logger 2025-11-16 23:19:31,037 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,037 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,037 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,039 | data_utils.py:393 | Observations info in 571313174000602109
# INFO logger 2025-11-16 23:19:31,039 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,039 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,039 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,047 | data_utils.py:393 | Observations info in 571313174000602116
# INFO logger 2025-11-16 23:19:31,047 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,048 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,048 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,049 | data_utils.py:393 | Observations info in 571313174000602123
# INFO logger 2025-11-16 23:19:31,050 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,050 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,050 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,051 | data_utils.py:393 | Observations info in 571313174000839574
# INFO logger 2025-11-16 23:19:31,051 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,052 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,052 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,053 | data_utils.py:393 | Observations info in 571313174000839604
# INFO logger 2025-11-16 23:19:31,053 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,053 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,054 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,055 | data_utils.py:393 | Observations info in 571313174000839611
# INFO logger 2025-11-16 23:19:31,055 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,055 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,055 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,056 | data_utils.py:393 | Observations info in 571313174000828844
# INFO logger 2025-11-16 23:19:31,057 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,057 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,057 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,058 | data_utils.py:393 | Observations info in 570715000000088872
# INFO logger 2025-11-16 23:19:31,058 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,059 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,059 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,060 | data_utils.py:393 | Observations info in 570715000000088865
# INFO logger 2025-11-16 23:19:31,061 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,061 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,061 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,062 | data_utils.py:393 | Observations info in 570715000000088858
# INFO logger 2025-11-16 23:19:31,063 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,063 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,063 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,065 | data_utils.py:393 | Observations info in 570715000000088810
# INFO logger 2025-11-16 23:19:31,065 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,065 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,065 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,066 | data_utils.py:393 | Observations info in 571313174001657979
# INFO logger 2025-11-16 23:19:31,066 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,066 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,067 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,068 | data_utils.py:393 | Observations info in 571313174001657962
# INFO logger 2025-11-16 23:19:31,068 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,068 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,068 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,069 | data_utils.py:393 | Observations info in 571313174001657931
# INFO logger 2025-11-16 23:19:31,069 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,070 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,070 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,071 | data_utils.py:393 | Observations info in 571313174000832759
# INFO logger 2025-11-16 23:19:31,071 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,071 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,071 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,073 | data_utils.py:393 | Observations info in 571313174000832742
# INFO logger 2025-11-16 23:19:31,073 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,073 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,073 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,074 | data_utils.py:393 | Observations info in 571313174000832711
# INFO logger 2025-11-16 23:19:31,074 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,074 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,075 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,076 | data_utils.py:393 | Observations info in 570715000000161025
# INFO logger 2025-11-16 23:19:31,076 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,076 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,076 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,077 | data_utils.py:393 | Observations info in 570715000000161001
# INFO logger 2025-11-16 23:19:31,077 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,078 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,078 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,079 | data_utils.py:393 | Observations info in 570715000000161018
# INFO logger 2025-11-16 23:19:31,079 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,079 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,080 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,081 | data_utils.py:393 | Observations info in 570715000000161032
# INFO logger 2025-11-16 23:19:31,081 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,081 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,081 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,083 | data_utils.py:393 | Observations info in 570715000000161056
# INFO logger 2025-11-16 23:19:31,091 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,091 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,091 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,096 | data_utils.py:393 | Observations info in 570715000000161049
# INFO logger 2025-11-16 23:19:31,097 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,097 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,097 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,098 | data_utils.py:393 | Observations info in 570715000000089336
# INFO logger 2025-11-16 23:19:31,098 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,099 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,099 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,100 | data_utils.py:393 | Observations info in 570715000000088827
# INFO logger 2025-11-16 23:19:31,100 | data_utils.py:394 | 	Total number of samples:  8760
# INFO logger 2025-11-16 23:19:31,100 | data_utils.py:395 | 	Number of samples for training: 7008
# INFO logger 2025-11-16 23:19:31,100 | data_utils.py:396 | 	Number of samples for validation:  1752
# INFO logger 2025-11-16 23:19:31,110 | data_utils.py:399 | Observations info using all data
# INFO logger 2025-11-16 23:19:31,110 | data_utils.py:400 | 	Total number of samples:  446760
# INFO logger 2025-11-16 23:19:31,111 | data_utils.py:401 | 	Number of samples for training: 357408
# INFO logger 2025-11-16 23:19:31,111 | data_utils.py:402 | 	Number of samples for validation:  89352

# %%
X_train.head()
# Out:
#                      Capacity_kw_lag-24  power_output_lag-24  age_lag-24  \
# time
# 2019-01-02 00:00:00                 1.0             0.951698    0.666667
# 2019-01-02 01:00:00                 1.0             0.951725    0.666667
# 2019-01-02 02:00:00                 1.0             0.951565    0.666667
# 2019-01-02 03:00:00                 1.0             0.021217    0.666667
# 2019-01-02 04:00:00                 1.0             0.000000    0.666667
#
#                      wind_dir_cos_lag-24  wind_dir_sin_lag-24  \
# time
# 2019-01-02 00:00:00              0.37905              0.01485
# 2019-01-02 01:00:00              0.37905              0.01485
# 2019-01-02 02:00:00              0.38750              0.01280
# 2019-01-02 03:00:00              0.35380              0.02185
# 2019-01-02 04:00:00              0.33720              0.02725
#
#                      hour_cos_lag-24  hour_sin_lag-24  temperature_c_lag-24  \
# time
# 2019-01-02 00:00:00          1.00000          0.50000              0.336986
# 2019-01-02 01:00:00          0.98295          0.62940              0.331507
# 2019-01-02 02:00:00          0.93300          0.75000              0.326027
# 2019-01-02 03:00:00          0.85355          0.85355              0.326027
# 2019-01-02 04:00:00          0.75000          0.93300              0.328767
#
#                      wind_speed_lag-24  Capacity_kw_lag-23  ...  \
# time                                                        ...
# 2019-01-02 00:00:00           0.500000                 1.0  ...
# 2019-01-02 01:00:00           0.575000                 1.0  ...
# 2019-01-02 02:00:00           0.620833                 1.0  ...
# 2019-01-02 03:00:00           0.666667                 1.0  ...
# 2019-01-02 04:00:00           0.695833                 1.0  ...
#
#                      Capacity_kw_lag-1  power_output_lag-1  age_lag-1  \
# time
# 2019-01-02 00:00:00                1.0            0.007541   0.666667
# 2019-01-02 01:00:00                1.0            0.000000   0.666667
# 2019-01-02 02:00:00                1.0            0.000000   0.666667
# 2019-01-02 03:00:00                1.0            0.000000   0.666667
# 2019-01-02 04:00:00                1.0            0.000000   0.666667
#
#                      wind_dir_cos_lag-1  wind_dir_sin_lag-1  hour_cos_lag-1  \
# time
# 2019-01-02 00:00:00             0.96985             0.32900         0.98295
# 2019-01-02 01:00:00             0.98065             0.36220         1.00000
# 2019-01-02 02:00:00             0.98905             0.39605         0.98295
# 2019-01-02 03:00:00             0.99515             0.43040         0.93300
# 2019-01-02 04:00:00             0.99625             0.43905         0.85355
#
#                      hour_sin_lag-1  temperature_c_lag-1  wind_speed_lag-1  \
# time
# 2019-01-02 00:00:00         0.37060             0.230137          0.808333
# 2019-01-02 01:00:00         0.50000             0.213699          0.787500
# 2019-01-02 02:00:00         0.62940             0.200000          0.754167
# 2019-01-02 03:00:00         0.75000             0.189041          0.737500
# 2019-01-02 04:00:00         0.85355             0.180822          0.695833
#
#                                    GSRN
# time
# 2019-01-02 00:00:00  570715000000128905
# 2019-01-02 01:00:00  570715000000128905
# 2019-01-02 02:00:00  570715000000128905
# 2019-01-02 03:00:00  570715000000128905
# 2019-01-02 04:00:00  570715000000128905
#
# [5 rows x 217 columns]

# %%
y_train.head()
# Out:
#                      power_output                GSRN
# time
# 2019-01-02 00:00:00           0.0  570715000000128905
# 2019-01-02 01:00:00           0.0  570715000000128905
# 2019-01-02 02:00:00           0.0  570715000000128905
# 2019-01-02 03:00:00           0.0  570715000000128905
# 2019-01-02 04:00:00           0.0  570715000000128905

# %%
x_scaler, y_scaler
# Out:
# (MinMaxScaler(), MinMaxScaler())

# %%
def make_postprocessing(X_train, X_val, y_train, y_val, exogenous_data_train, exogenous_data_val, x_scaler, y_scaler):
    """Make data ready to be fed into ml algorithms"""
    # if there are more than one specified areas, get the data per area
    if X_train[args.identifier].nunique() != 1:
        area_X_train, area_X_val, area_y_train, area_y_val = get_data_by_area(X_train, X_val,
                                                                              y_train, y_val, 
                                                                              identifier=args.identifier)
    else:
        area_X_train, area_X_val, area_y_train, area_y_val = None, None, None, None

    # Get the exogenous data per area.
    if exogenous_data_train is not None:
        exogenous_data_train, exogenous_data_val = get_exogenous_data_by_area(exogenous_data_train,
                                                                              exogenous_data_val)
    # transform to np
    if area_X_train is not None:
        for area in area_X_train:
            tmp_X_train, tmp_y_train, tmp_X_val, tmp_y_val = remove_identifiers(
                area_X_train[area], area_y_train[area], area_X_val[area], area_y_val[area])
            tmp_X_train, tmp_y_train = tmp_X_train.to_numpy(), tmp_y_train.to_numpy()
            tmp_X_val, tmp_y_val = tmp_X_val.to_numpy(), tmp_y_val.to_numpy()
            area_X_train[area] = tmp_X_train
            area_X_val[area] = tmp_X_val
            area_y_train[area] = tmp_y_train
            area_y_val[area] = tmp_y_val
    
    if exogenous_data_train is not None:
        for area in exogenous_data_train:
            exogenous_data_train[area] = exogenous_data_train[area].to_numpy()
            exogenous_data_val[area] = exogenous_data_val[area].to_numpy()
    
    # remove identifiers from features, targets
    X_train, y_train, X_val, y_val = remove_identifiers(X_train, y_train, X_val, y_val)
    assert len(X_train.columns) == len(X_val.columns)
    
    num_features = len(X_train.columns) // args.num_lags
    
    # to timeseries representation
    X_train = to_timeseries_rep(X_train.to_numpy(), num_lags=args.num_lags,
                                            num_features=num_features)
    X_val = to_timeseries_rep(X_val.to_numpy(), num_lags=args.num_lags,
                                          num_features=num_features)
    
    if area_X_train is not None:
        area_X_train = to_timeseries_rep(area_X_train, num_lags=args.num_lags,
                                                     num_features=num_features)
        area_X_val = to_timeseries_rep(area_X_val, num_lags=args.num_lags,
                                                   num_features=num_features)
    
    # transform targets to numpy
    y_train, y_val = y_train.to_numpy(), y_val.to_numpy()
    
    # centralized (all) learning specific
    if not args.filter_bs and exogenous_data_train is not None:
        exogenous_data_train_combined, exogenous_data_val_combined = [], []
        for area in exogenous_data_train:
            exogenous_data_train_combined.extend(exogenous_data_train[area])
            exogenous_data_val_combined.extend(exogenous_data_val[area])
        exogenous_data_train_combined = np.stack(exogenous_data_train_combined)
        exogenous_data_val_combined = np.stack(exogenous_data_val_combined)
        exogenous_data_train["all"] = exogenous_data_train_combined
        exogenous_data_val["all"] = exogenous_data_val_combined
    return X_train, X_val, y_train, y_val, area_X_train, area_X_val, area_y_train, area_y_val, exogenous_data_train, exogenous_data_val

# %%
X_train, X_val, y_train, y_val, area_X_train, area_X_val, area_y_train, area_y_val, exogenous_data_train, exogenous_data_val = make_postprocessing(X_train, X_val, y_train, y_val, exogenous_data_train, exogenous_data_val, x_scaler, y_scaler)

# %%
area_X_train.keys()
# Out:
# dict_keys([np.int64(570715000000128905), np.int64(570715000000088643), np.int64(570715000000088667), np.int64(570715000000125669), np.int64(570715000000125706), np.int64(570715000000125652), np.int64(570715000000125683), np.int64(571313161170169709), np.int64(571313161170169150), np.int64(571313161170169785), np.int64(570715000000125621), np.int64(570715000000125614), np.int64(571313174001641268), np.int64(570715000000125591), np.int64(571313174001641251), np.int64(570715000000125546), np.int64(571313174001641244), np.int64(571313174001641237), np.int64(571313174001641220), np.int64(570715000000084652), np.int64(571313174000780944), np.int64(570715000000084607), np.int64(571313174000780951), np.int64(571313174000602154), np.int64(571313174000602147), np.int64(571313174000602130), np.int64(571313174000602109), np.int64(571313174000602116), np.int64(571313174000602123), np.int64(571313174000839574), np.int64(571313174000839604), np.int64(571313174000839611), np.int64(571313174000828844), np.int64(570715000000088872), np.int64(570715000000088865), np.int64(570715000000088858), np.int64(570715000000088810), np.int64(571313174001657979), np.int64(571313174001657962), np.int64(571313174001657931), np.int64(571313174000832759), np.int64(571313174000832742), np.int64(571313174000832711), np.int64(570715000000161025), np.int64(570715000000161001), np.int64(570715000000161018), np.int64(570715000000161032), np.int64(570715000000161056), np.int64(570715000000161049), np.int64(570715000000089336), np.int64(570715000000088827)])

# %%
area_X_val.keys()
# Out:
# dict_keys([np.int64(570715000000128905), np.int64(570715000000088643), np.int64(570715000000088667), np.int64(570715000000125669), np.int64(570715000000125706), np.int64(570715000000125652), np.int64(570715000000125683), np.int64(571313161170169709), np.int64(571313161170169150), np.int64(571313161170169785), np.int64(570715000000125621), np.int64(570715000000125614), np.int64(571313174001641268), np.int64(570715000000125591), np.int64(571313174001641251), np.int64(570715000000125546), np.int64(571313174001641244), np.int64(571313174001641237), np.int64(571313174001641220), np.int64(570715000000084652), np.int64(571313174000780944), np.int64(570715000000084607), np.int64(571313174000780951), np.int64(571313174000602154), np.int64(571313174000602147), np.int64(571313174000602130), np.int64(571313174000602109), np.int64(571313174000602116), np.int64(571313174000602123), np.int64(571313174000839574), np.int64(571313174000839604), np.int64(571313174000839611), np.int64(571313174000828844), np.int64(570715000000088872), np.int64(570715000000088865), np.int64(570715000000088858), np.int64(570715000000088810), np.int64(571313174001657979), np.int64(571313174001657962), np.int64(571313174001657931), np.int64(571313174000832759), np.int64(571313174000832742), np.int64(571313174000832711), np.int64(570715000000161025), np.int64(570715000000161001), np.int64(570715000000161018), np.int64(570715000000161032), np.int64(570715000000161056), np.int64(570715000000161049), np.int64(570715000000089336), np.int64(570715000000088827)])

# %%
X_train[:2]
# Out:
# array([[[[1.        ],
#          [0.95169818],
#          [0.66666669],
#          [0.37905002],
#          [0.01484999],
#          [1.        ],
#          [0.5       ],
#          [0.3369863 ],
#          [0.50000006]],
#
#         [[1.        ],
#          [0.95172477],
#          [0.66666669],
#          [0.37905002],
#          [0.01484999],
#          [0.98294997],
#          [0.62940001],
#          [0.33150685],
#          [0.57499999]],
#
#         [[1.        ],
#          [0.95156538],
#          [0.66666669],
#          [0.38749999],
#          [0.01280001],
#          [0.93299997],
#          [0.75      ],
#          [0.32602739],
#          [0.62083334]],
#
#         [[1.        ],
#          [0.02121671],
#          [0.66666669],
#          [0.3538    ],
#          [0.02184999],
#          [0.85354996],
#          [0.85354996],
#          [0.32602739],
#          [0.66666669]],
#
#         [[1.        ],
#          [0.        ],
#          [0.66666669],
#          [0.33719999],
#          [0.02724999],
#          [0.75      ],
#          [0.93299997],
#          [0.32876712],
#          [0.69583333]],
#
#         [[1.        ],
#          [0.        ],
#          [0.66666669],
#          [0.39605001],
#          [0.01095   ],
#          [0.62940001],
#          [0.98294997],
#          [0.34246576],
#          [0.69166672]],
#
#         [[1.        ],
#          [0.        ],
#          [0.66666669],
#          [0.6462    ],
#          [0.02184999],
#          [0.5       ],
#          [1.        ],
#          [0.37534246],
#          [0.71250004]],
#
#         [[1.        ],
#          [0.04012321],
#          [0.66666669],
#          [0.63779998],
#          [0.01934999],
#          [0.37059999],
#          [0.98294997],
#          [0.33972603],
#          [0.67083341]],
#
#         [[1.        ],
#          [0.95047665],
#          [0.66666669],
#          [0.59539998],
#          [0.00920001],
#          [0.25      ],
#          [0.93299997],
#          [0.3068493 ],
#          [0.70416671]],
#
#         [[1.        ],
#          [0.95005184],
#          [0.66666669],
#          [0.60395002],
#          [0.01095   ],
#          [0.14645001],
#          [0.85354996],
#          [0.30958903],
#          [0.75416672]],
#
#         [[1.        ],
#          [0.63535941],
#          [0.66666669],
#          [0.65450001],
#          [0.02445   ],
#          [0.067     ],
#          [0.75      ],
#          [0.31506848],
#          [0.83750004]],
#
#         [[1.        ],
#          [0.63530636],
#          [0.66666669],
#          [0.68729997],
#          [0.03639999],
#          [0.01705   ],
#          [0.62940001],
#          [0.30958903],
#          [0.86666667]],
#
#         [[1.        ],
#          [0.40094003],
#          [0.66666669],
#          [0.67919999],
#          [0.0332    ],
#          [0.        ],
#          [0.5       ],
#          [0.30136985],
#          [0.85000002]],
#
#         [[1.        ],
#          [0.68817556],
#          [0.66666669],
#          [0.68729997],
#          [0.03639999],
#          [0.01705   ],
#          [0.37059999],
#          [0.29315066],
#          [0.86666667]],
#
#         [[1.        ],
#          [0.95050323],
#          [0.66666669],
#          [0.70335001],
#          [0.04324999],
#          [0.067     ],
#          [0.25      ],
#          [0.28219178],
#          [0.86666667]],
#
#         [[1.        ],
#          [0.95066261],
#          [0.66666669],
#          [0.71130002],
#          [0.04685   ],
#          [0.14645001],
#          [0.14645001],
#          [0.27945206],
#          [0.81666672]],
#
#         [[1.        ],
#          [0.95084846],
#          [0.66666669],
#          [0.727     ],
#          [0.05450001],
#          [0.25      ],
#          [0.067     ],
#          [0.27945206],
#          [0.77916664]],
#
#         [[1.        ],
#          [0.95106089],
#          [0.66666669],
#          [0.7723    ],
#          [0.08065   ],
#          [0.37059999],
#          [0.01705   ],
#          [0.27123287],
#          [0.68750006]],
#
#         [[1.        ],
#          [0.95095468],
#          [0.66666669],
#          [0.88855004],
#          [0.18535   ],
#          [0.5       ],
#          [0.        ],
#          [0.25205481],
#          [0.65833336]],
#
#         [[1.        ],
#          [0.95005184],
#          [0.66666669],
#          [0.96025002],
#          [0.30465001],
#          [0.62940001],
#          [0.01705   ],
#          [0.29863015],
#          [0.66250002]],
#
#         [[1.        ],
#          [0.95100772],
#          [0.66666669],
#          [0.96679997],
#          [0.32080001],
#          [0.75      ],
#          [0.067     ],
#          [0.28493151],
#          [0.74583334]],
#
#         [[1.        ],
#          [0.03664463],
#          [0.66666669],
#          [0.96679997],
#          [0.32080001],
#          [0.85354996],
#          [0.14645001],
#          [0.27945206],
#          [0.77083337]],
#
#         [[1.        ],
#          [0.95071572],
#          [0.66666669],
#          [0.95675004],
#          [0.29664999],
#          [0.93299997],
#          [0.25      ],
#          [0.25479454],
#          [0.82499999]],
#
#         [[1.        ],
#          [0.00754136],
#          [0.66666669],
#          [0.96985   ],
#          [0.329     ],
#          [0.98294997],
#          [0.37059999],
#          [0.23013699],
#          [0.80833334]]],
#
#
#        [[[1.        ],
#          [0.95172477],
#          [0.66666669],
#          [0.37905002],
#          [0.01484999],
#          [0.98294997],
#          [0.62940001],
#          [0.33150685],
#          [0.57499999]],
#
#         [[1.        ],
#          [0.95156538],
#          [0.66666669],
#          [0.38749999],
#          [0.01280001],
#          [0.93299997],
#          [0.75      ],
#          [0.32602739],
#          [0.62083334]],
#
#         [[1.        ],
#          [0.02121671],
#          [0.66666669],
#          [0.3538    ],
#          [0.02184999],
#          [0.85354996],
#          [0.85354996],
#          [0.32602739],
#          [0.66666669]],
#
#         [[1.        ],
#          [0.        ],
#          [0.66666669],
#          [0.33719999],
#          [0.02724999],
#          [0.75      ],
#          [0.93299997],
#          [0.32876712],
#          [0.69583333]],
#
#         [[1.        ],
#          [0.        ],
#          [0.66666669],
#          [0.39605001],
#          [0.01095   ],
#          [0.62940001],
#          [0.98294997],
#          [0.34246576],
#          [0.69166672]],
#
#         [[1.        ],
#          [0.        ],
#          [0.66666669],
#          [0.6462    ],
#          [0.02184999],
#          [0.5       ],
#          [1.        ],
#          [0.37534246],
#          [0.71250004]],
#
#         [[1.        ],
#          [0.04012321],
#          [0.66666669],
#          [0.63779998],
#          [0.01934999],
#          [0.37059999],
#          [0.98294997],
#          [0.33972603],
#          [0.67083341]],
#
#         [[1.        ],
#          [0.95047665],
#          [0.66666669],
#          [0.59539998],
#          [0.00920001],
#          [0.25      ],
#          [0.93299997],
#          [0.3068493 ],
#          [0.70416671]],
#
#         [[1.        ],
#          [0.95005184],
#          [0.66666669],
#          [0.60395002],
#          [0.01095   ],
#          [0.14645001],
#          [0.85354996],
#          [0.30958903],
#          [0.75416672]],
#
#         [[1.        ],
#          [0.63535941],
#          [0.66666669],
#          [0.65450001],
#          [0.02445   ],
#          [0.067     ],
#          [0.75      ],
#          [0.31506848],
#          [0.83750004]],
#
#         [[1.        ],
#          [0.63530636],
#          [0.66666669],
#          [0.68729997],
#          [0.03639999],
#          [0.01705   ],
#          [0.62940001],
#          [0.30958903],
#          [0.86666667]],
#
#         [[1.        ],
#          [0.40094003],
#          [0.66666669],
#          [0.67919999],
#          [0.0332    ],
#          [0.        ],
#          [0.5       ],
#          [0.30136985],
#          [0.85000002]],
#
#         [[1.        ],
#          [0.68817556],
#          [0.66666669],
#          [0.68729997],
#          [0.03639999],
#          [0.01705   ],
#          [0.37059999],
#          [0.29315066],
#          [0.86666667]],
#
#         [[1.        ],
#          [0.95050323],
#          [0.66666669],
#          [0.70335001],
#          [0.04324999],
#          [0.067     ],
#          [0.25      ],
#          [0.28219178],
#          [0.86666667]],
#
#         [[1.        ],
#          [0.95066261],
#          [0.66666669],
#          [0.71130002],
#          [0.04685   ],
#          [0.14645001],
#          [0.14645001],
#          [0.27945206],
#          [0.81666672]],
#
#         [[1.        ],
#          [0.95084846],
#          [0.66666669],
#          [0.727     ],
#          [0.05450001],
#          [0.25      ],
#          [0.067     ],
#          [0.27945206],
#          [0.77916664]],
#
#         [[1.        ],
#          [0.95106089],
#          [0.66666669],
#          [0.7723    ],
#          [0.08065   ],
#          [0.37059999],
#          [0.01705   ],
#          [0.27123287],
#          [0.68750006]],
#
#         [[1.        ],
#          [0.95095468],
#          [0.66666669],
#          [0.88855004],
#          [0.18535   ],
#          [0.5       ],
#          [0.        ],
#          [0.25205481],
#          [0.65833336]],
#
#         [[1.        ],
#          [0.95005184],
#          [0.66666669],
#          [0.96025002],
#          [0.30465001],
#          [0.62940001],
#          [0.01705   ],
#          [0.29863015],
#          [0.66250002]],
#
#         [[1.        ],
#          [0.95100772],
#          [0.66666669],
#          [0.96679997],
#          [0.32080001],
#          [0.75      ],
#          [0.067     ],
#          [0.28493151],
#          [0.74583334]],
#
#         [[1.        ],
#          [0.03664463],
#          [0.66666669],
#          [0.96679997],
#          [0.32080001],
#          [0.85354996],
#          [0.14645001],
#          [0.27945206],
#          [0.77083337]],
#
#         [[1.        ],
#          [0.95071572],
#          [0.66666669],
#          [0.95675004],
#          [0.29664999],
#          [0.93299997],
#          [0.25      ],
#          [0.25479454],
#          [0.82499999]],
#
#         [[1.        ],
#          [0.00754136],
#          [0.66666669],
#          [0.96985   ],
#          [0.329     ],
#          [0.98294997],
#          [0.37059999],
#          [0.23013699],
#          [0.80833334]],
#
#         [[1.        ],
#          [0.        ],
#          [0.66666669],
#          [0.98065001],
#          [0.36220002],
#          [1.        ],
#          [0.5       ],
#          [0.21369863],
#          [0.78750002]]]])

# %%
y_train[:2]
# Out:
# array([[0.],
#        [0.]], dtype=float32)

# %%
len(X_train), len(X_val)
# Out:
# (356184, 88128)

# %%
def get_input_dims(X_train, exogenous_data_train):
    if args.model_name == "mlp":
        input_dim = X_train.shape[1] * X_train.shape[2]
    else:
        input_dim = X_train.shape[2]
    
    if exogenous_data_train is not None:
        if len(exogenous_data_train) == 1:
            cid = next(iter(exogenous_data_train.keys()))
            exogenous_dim = exogenous_data_train[cid].shape[1]
        else:
            exogenous_dim = exogenous_data_train["all"].shape[1]
    else:
        exogenous_dim = 0
    
    return input_dim, exogenous_dim

# %%
def get_model(model: str,
              input_dim: int,
              out_dim: int,
              lags: int = 10,
              exogenous_dim: int = 0,
              seed=0):
    if model == "mlp":
        model = MLP(input_dim=input_dim, layer_units=[256, 128, 64], num_outputs=out_dim)
    elif model == "rnn":
        model = RNN(input_dim=input_dim, rnn_hidden_size=128, num_rnn_layers=1, rnn_dropout=0.0,
                    layer_units=[128], num_outputs=out_dim, matrix_rep=True, exogenous_dim=exogenous_dim)
    elif model == "lstm":
        model = LSTM(input_dim=input_dim, lstm_hidden_size=128, num_lstm_layers=1, lstm_dropout=0.0,
                     layer_units=[128], num_outputs=out_dim, matrix_rep=True, exogenous_dim=exogenous_dim)
    elif model == "gru":
        model = GRU(input_dim=input_dim, gru_hidden_size=128, num_gru_layers=1, gru_dropout=0.0,
                    layer_units=[128], num_outputs=out_dim, matrix_rep=True, exogenous_dim=exogenous_dim)
    elif model == "cnn":
        model = CNN(num_features=input_dim, lags=lags, exogenous_dim=exogenous_dim, out_dim=out_dim)
    elif model == "da_encoder_decoder":
        model = DualAttentionAutoEncoder(input_dim=input_dim, architecture="lstm", matrix_rep=True)
    else:
        raise NotImplementedError("Specified model is not implemented. Plese define your own model or choose one from ['mlp', 'rnn', 'lstm', 'gru', 'cnn', 'da_encoder_decoder']")
    return model

# %%
# define the model
args.model_name = "lstm"

input_dim, exogenous_dim = get_input_dims(X_train, exogenous_data_train)

print(input_dim, exogenous_dim)

model = get_model(model=args.model_name,
                  input_dim=input_dim,
                  out_dim=y_train.shape[1],
                  lags=args.num_lags,
                  exogenous_dim=exogenous_dim,
                  seed=args.seed)
# Out:
# 9 0

# %%
model
# Out:
# LSTM(
#   (lstm): LSTM(9, 128, batch_first=True)
#   (MLP_layers): Sequential(
#     (0): Linear(in_features=128, out_features=1, bias=True)
#   )
# )

# %%
def fit(model, X_train, y_train, X_val, y_val, 
        exogenous_data_train=None, exogenous_data_val=None, 
        idxs=[], # the indices of our targets in X
        log_per=1):
    
    # get exogenous data (if any)
    if exogenous_data_train is not None and len(exogenous_data_train) > 1:
        exogenous_data_train = exogenous_data_train["all"]
        exogenous_data_val = exogenous_data_val["all"]
    elif exogenous_data_train is not None and len(exogenous_data_train) == 1:
        cid = next(iter(exogenous_data_train.keys()))
        exogenous_data_train = exogenous_data_train[cid]
        exogenous_data_val = exogenous_data_val[cid]
    else:
        exogenous_data_train = None
        exogenous_data_val = None
    num_features = len(X_train[0][0])
    
    # to torch loader
    train_loader = to_torch_dataset(X_train, y_train,
                                    num_lags=args.num_lags,
                                    num_features=num_features,
                                    exogenous_data=exogenous_data_train,
                                    indices=idxs,
                                    batch_size=args.batch_size, 
                                    shuffle=False)
    val_loader = to_torch_dataset(X_val, y_val, 
                                  num_lags=args.num_lags,
                                  num_features=num_features,
                                  exogenous_data=exogenous_data_val,
                                  indices=idxs,
                                  batch_size=args.batch_size,
                                  shuffle=False)
    
    # train the model
    model = train(model, 
                  train_loader, val_loader,
                  epochs=args.epochs,
                  optimizer=args.optimizer, lr=args.lr,
                  criterion=args.criterion,
                  early_stopping=args.early_stopping,
                  patience=args.patience,
                  plot_history=args.plot_history, 
                  device=device, log_per=log_per,
                  use_carbontracker=False)
    
    return model

# %%
trained_model = fit(model, X_train, y_train, X_val, y_val)
# Out:
# INFO logger 2025-11-17 00:19:57,653 | train_utils.py:97 | Epoch 1 [Train]: loss 0.01608129003320703, mse: 0.00834991317242384, rmse: 0.09137785931189152, mae 0.06346059590578079, r2: 0.8491501808166504, nrmse: 0.3958864212036133, sse: 2974.10546875, sst: 19715.66796875
# INFO logger 2025-11-17 00:19:57,659 | train_utils.py:99 | Epoch 1 [Test]: loss 8.110110731250975e-06, mse: 0.008151977322995663, rmse: 0.09028830114137525, mae 0.06331107020378113, r2: 0.8743984699249268, nrmse: 0.33881261944770813, sse: 718.4174194335938, sst: 5719.81591796875
# INFO logger 2025-11-17 00:19:57,660 | helpers.py:154 | Validation loss decreased (inf --> 0.000008). Caching model ...
# INFO logger 2025-11-17 00:20:24,051 | train_utils.py:97 | Epoch 2 [Train]: loss 0.0072750698125402, mse: 0.006942851468920708, rmse: 0.08332377493201269, mae 0.05472579225897789, r2: 0.8745701909065247, nrmse: 0.36099281907081604, sse: 2472.9326171875, sst: 19715.66796875
# INFO logger 2025-11-17 00:20:24,052 | train_utils.py:99 | Epoch 2 [Test]: loss 6.670993003517744e-06, mse: 0.00672871945425868, rmse: 0.08202877211234287, mae 0.05380767211318016, r2: 0.8963273167610168, nrmse: 0.307818204164505, sse: 592.9885864257812, sst: 5719.81591796875
# INFO logger 2025-11-17 00:20:24,052 | helpers.py:154 | Validation loss decreased (0.000008 --> 0.000007). Caching model ...
# INFO logger 2025-11-17 00:20:50,144 | train_utils.py:97 | Epoch 3 [Train]: loss 0.006805941387582785, mse: 0.006820281967520714, rmse: 0.08258499844112557, mae 0.054572977125644684, r2: 0.8767845034599304, nrmse: 0.3577921390533447, sse: 2429.275390625, sst: 19715.66796875
# INFO logger 2025-11-17 00:20:50,144 | train_utils.py:99 | Epoch 3 [Test]: loss 6.526722478478763e-06, mse: 0.006576097570359707, rmse: 0.08109314132748655, mae 0.05344123765826225, r2: 0.8986788392066956, nrmse: 0.3043071925640106, sse: 579.538330078125, sst: 5719.81591796875
# INFO logger 2025-11-17 00:20:50,145 | helpers.py:154 | Validation loss decreased (0.000007 --> 0.000007). Caching model ...
# INFO logger 2025-11-17 00:21:16,052 | train_utils.py:97 | Epoch 4 [Train]: loss 0.0065461530352824895, mse: 0.006464825011789799, rmse: 0.08040413553909898, mae 0.05217159539461136, r2: 0.8832062482833862, nrmse: 0.34834372997283936, sse: 2302.667236328125, sst: 19715.66796875
# INFO logger 2025-11-17 00:21:16,053 | train_utils.py:99 | Epoch 4 [Test]: loss 6.146663775681582e-06, mse: 0.006195848807692528, rmse: 0.07871371422879578, mae 0.05070388689637184, r2: 0.904537558555603, nrmse: 0.2953782379627228, sse: 546.0277709960938, sst: 5719.81591796875
# INFO logger 2025-11-17 00:21:16,053 | helpers.py:154 | Validation loss decreased (0.000007 --> 0.000006). Caching model ...
# INFO logger 2025-11-17 00:21:41,687 | train_utils.py:97 | Epoch 5 [Train]: loss 0.00648868995606257, mse: 0.006479417439550161, rmse: 0.08049482865097708, mae 0.052034080028533936, r2: 0.8829426169395447, nrmse: 0.34873664379119873, sse: 2307.86474609375, sst: 19715.66796875
# INFO logger 2025-11-17 00:21:41,688 | train_utils.py:99 | Epoch 5 [Test]: loss 6.160671587190716e-06, mse: 0.006212848704308271, rmse: 0.07882162586694258, mae 0.050593528896570206, r2: 0.9042755961418152, nrmse: 0.2957831919193268, sse: 547.5259399414062, sst: 5719.81591796875
# INFO logger 2025-11-17 00:21:41,688 | helpers.py:142 | EarlyStopping counter: 1 out of 10
# INFO logger 2025-11-17 00:22:08,087 | train_utils.py:97 | Epoch 6 [Train]: loss 0.006500709369703699, mse: 0.0065086400136351585, rmse: 0.08067614277861306, mae 0.05236569419503212, r2: 0.8824146389961243, nrmse: 0.349522203207016, sse: 2318.2734375, sst: 19715.66796875
# INFO logger 2025-11-17 00:22:08,087 | train_utils.py:99 | Epoch 6 [Test]: loss 6.207799029367629e-06, mse: 0.0062614730559289455, rmse: 0.07912947021135011, mae 0.05100104585289955, r2: 0.9035264253616333, nrmse: 0.29693838953971863, sse: 551.8110961914062, sst: 5719.81591796875
# INFO logger 2025-11-17 00:22:08,087 | helpers.py:142 | EarlyStopping counter: 2 out of 10
# INFO logger 2025-11-17 00:22:34,964 | train_utils.py:97 | Epoch 7 [Train]: loss 0.0064831551431341035, mse: 0.006523131392896175, rmse: 0.08076590489121122, mae 0.05247396603226662, r2: 0.8821528553962708, nrmse: 0.34991106390953064, sse: 2323.43505859375, sst: 19715.66796875
# INFO logger 2025-11-17 00:22:34,964 | train_utils.py:99 | Epoch 7 [Test]: loss 6.234809204341862e-06, mse: 0.0062896497547626495, rmse: 0.07930731211409607, mae 0.05110904201865196, r2: 0.9030922651290894, nrmse: 0.2976057529449463, sse: 554.2942504882812, sst: 5719.81591796875
# INFO logger 2025-11-17 00:22:34,965 | helpers.py:142 | EarlyStopping counter: 3 out of 10
# INFO logger 2025-11-17 00:23:01,190 | train_utils.py:97 | Epoch 8 [Train]: loss 0.0064614033701176615, mse: 0.006548022851347923, rmse: 0.08091985449410993, mae 0.05247807875275612, r2: 0.8817031383514404, nrmse: 0.35057803988456726, sse: 2332.301025390625, sst: 19715.66796875
# INFO logger 2025-11-17 00:23:01,190 | train_utils.py:99 | Epoch 8 [Test]: loss 6.263740311385036e-06, mse: 0.006319890730082989, rmse: 0.07949774040866187, mae 0.05106474086642265, r2: 0.9026263356208801, nrmse: 0.29832035303115845, sse: 556.9593505859375, sst: 5719.81591796875
# INFO logger 2025-11-17 00:23:01,191 | helpers.py:142 | EarlyStopping counter: 4 out of 10
# INFO logger 2025-11-17 00:23:27,215 | train_utils.py:97 | Epoch 9 [Train]: loss 0.006443349977061367, mse: 0.006616566330194473, rmse: 0.08134227886034712, mae 0.05269214138388634, r2: 0.8804648518562317, nrmse: 0.35240817070007324, sse: 2356.715087890625, sst: 19715.66796875
# INFO logger 2025-11-17 00:23:27,215 | train_utils.py:99 | Epoch 9 [Test]: loss 6.341693462901522e-06, mse: 0.006400087382644415, rmse: 0.08000054613966341, mae 0.05132520943880081, r2: 0.9013907313346863, nrmse: 0.3002071678638458, sse: 564.0269165039062, sst: 5719.81591796875
# INFO logger 2025-11-17 00:23:27,216 | helpers.py:142 | EarlyStopping counter: 5 out of 10
# INFO logger 2025-11-17 00:23:52,950 | train_utils.py:97 | Epoch 10 [Train]: loss 0.0064327571967258065, mse: 0.006705110892653465, rmse: 0.08188474151301611, mae 0.05310555174946785, r2: 0.8788652420043945, nrmse: 0.3547583222389221, sse: 2388.253173828125, sst: 19715.66796875
# INFO logger 2025-11-17 00:23:52,950 | train_utils.py:99 | Epoch 10 [Test]: loss 6.446679985800321e-06, mse: 0.006507248617708683, rmse: 0.08066751897578531, mae 0.05185806378722191, r2: 0.8997396230697632, nrmse: 0.30271002650260925, sse: 573.4708251953125, sst: 5719.81591796875
# INFO logger 2025-11-17 00:23:52,950 | helpers.py:142 | EarlyStopping counter: 6 out of 10
# INFO logger 2025-11-17 00:24:18,620 | train_utils.py:97 | Epoch 11 [Train]: loss 0.006443848798650949, mse: 0.006690713111311197, rmse: 0.08179677934559036, mae 0.053082384169101715, r2: 0.8791252970695496, nrmse: 0.35437723994255066, sse: 2383.125, sst: 19715.66796875
# INFO logger 2025-11-17 00:24:18,621 | train_utils.py:99 | Epoch 11 [Test]: loss 6.424780978186978e-06, mse: 0.0064833639189600945, rmse: 0.08051933878864191, mae 0.05170493200421333, r2: 0.9001076221466064, nrmse: 0.30215397477149963, sse: 571.3659057617188, sst: 5719.81591796875
# INFO logger 2025-11-17 00:24:18,621 | helpers.py:142 | EarlyStopping counter: 7 out of 10
# INFO logger 2025-11-17 00:24:44,419 | train_utils.py:97 | Epoch 12 [Train]: loss 0.006499696259344018, mse: 0.006488736253231764, rmse: 0.08055269240212747, mae 0.05250678211450577, r2: 0.8827742338180542, nrmse: 0.348987340927124, sse: 2311.18408203125, sst: 19715.66796875
# INFO logger 2025-11-17 00:24:44,419 | train_utils.py:99 | Epoch 12 [Test]: loss 6.188288242557846e-06, mse: 0.006238145288079977, rmse: 0.07898193013645576, mae 0.050804924219846725, r2: 0.9038858413696289, nrmse: 0.2963847219944, sse: 549.7552490234375, sst: 5719.81591796875
# INFO logger 2025-11-17 00:24:44,419 | helpers.py:142 | EarlyStopping counter: 8 out of 10
# INFO logger 2025-11-17 00:25:09,971 | train_utils.py:97 | Epoch 13 [Train]: loss 0.006396564180981475, mse: 0.006380399223417044, rmse: 0.07987740120595464, mae 0.0520642027258873, r2: 0.8847314715385437, nrmse: 0.34606170654296875, sse: 2272.59619140625, sst: 19715.66796875
# INFO logger 2025-11-17 00:25:09,972 | train_utils.py:99 | Epoch 13 [Test]: loss 6.092800503460042e-06, mse: 0.0061432672664523125, rmse: 0.07837899761066297, mae 0.05041695758700371, r2: 0.9053477048873901, nrmse: 0.29412218928337097, sse: 541.3938598632812, sst: 5719.81591796875
# INFO logger 2025-11-17 00:25:09,972 | helpers.py:154 | Validation loss decreased (0.000006 --> 0.000006). Caching model ...
# INFO logger 2025-11-17 00:25:36,119 | train_utils.py:97 | Epoch 14 [Train]: loss 0.006366906600640337, mse: 0.006376217119395733, rmse: 0.07985121864690439, mae 0.051891911774873734, r2: 0.8848070502281189, nrmse: 0.3459482789039612, sse: 2271.1064453125, sst: 19715.66796875
# INFO logger 2025-11-17 00:25:36,120 | train_utils.py:99 | Epoch 14 [Test]: loss 6.0912566688980366e-06, mse: 0.006142314989119768, rmse: 0.07837292255058355, mae 0.050326280295848846, r2: 0.9053623676300049, nrmse: 0.2940994203090668, sse: 541.3099365234375, sst: 5719.81591796875
# INFO logger 2025-11-17 00:25:36,120 | helpers.py:154 | Validation loss decreased (0.000006 --> 0.000006). Caching model ...
# INFO logger 2025-11-17 00:26:02,108 | train_utils.py:97 | Epoch 15 [Train]: loss 0.006358466933724931, mse: 0.0063884141854941845, rmse: 0.07992755585837831, mae 0.05188680440187454, r2: 0.8845866918563843, nrmse: 0.34627899527549744, sse: 2275.450927734375, sst: 19715.66796875
# INFO logger 2025-11-17 00:26:02,108 | train_utils.py:99 | Epoch 15 [Test]: loss 6.113605832135929e-06, mse: 0.006165011320263147, rmse: 0.07851758605728494, mae 0.05037638172507286, r2: 0.9050126671791077, nrmse: 0.29464226961135864, sse: 543.3101196289062, sst: 5719.81591796875
# INFO logger 2025-11-17 00:26:02,109 | helpers.py:142 | EarlyStopping counter: 1 out of 10
# INFO logger 2025-11-17 00:26:27,804 | train_utils.py:97 | Epoch 16 [Train]: loss 0.006350103425846874, mse: 0.006389440502971411, rmse: 0.0799339758986841, mae 0.051922980695962906, r2: 0.8845681548118591, nrmse: 0.34630683064460754, sse: 2275.81640625, sst: 19715.66796875
# INFO logger 2025-11-17 00:26:27,804 | train_utils.py:99 | Epoch 16 [Test]: loss 6.129724548483868e-06, mse: 0.006181266624480486, rmse: 0.07862103169305582, mae 0.0504695363342762, r2: 0.9047622084617615, nrmse: 0.2950304448604584, sse: 544.74267578125, sst: 5719.81591796875
# INFO logger 2025-11-17 00:26:27,804 | helpers.py:142 | EarlyStopping counter: 2 out of 10
# INFO logger 2025-11-17 00:26:53,590 | train_utils.py:97 | Epoch 17 [Train]: loss 0.00633823314290922, mse: 0.006373721174895763, rmse: 0.0798355883982561, mae 0.05195492506027222, r2: 0.8848521113395691, nrmse: 0.34588053822517395, sse: 2270.217529296875, sst: 19715.66796875
# INFO logger 2025-11-17 00:26:53,591 | train_utils.py:99 | Epoch 17 [Test]: loss 6.128511151774687e-06, mse: 0.0061797210946679115, rmse: 0.07861120209402672, mae 0.05056067183613777, r2: 0.9047859907150269, nrmse: 0.2949935495853424, sse: 544.6064453125, sst: 5719.81591796875
# INFO logger 2025-11-17 00:26:53,591 | helpers.py:142 | EarlyStopping counter: 3 out of 10
# INFO logger 2025-11-17 00:27:19,329 | train_utils.py:97 | Epoch 18 [Train]: loss 0.0063248577684260395, mse: 0.006333985365927219, rmse: 0.0795863390659931, mae 0.05180728808045387, r2: 0.8855699896812439, nrmse: 0.3448007106781006, sse: 2256.064208984375, sst: 19715.66796875
# INFO logger 2025-11-17 00:27:19,330 | train_utils.py:99 | Epoch 18 [Test]: loss 6.10100877174185e-06, mse: 0.006151742301881313, rmse: 0.07843304343120515, mae 0.05039746314287186, r2: 0.9052171111106873, nrmse: 0.2943250238895416, sse: 542.1407470703125, sst: 5719.81591796875
# INFO logger 2025-11-17 00:27:19,330 | helpers.py:142 | EarlyStopping counter: 4 out of 10
# INFO logger 2025-11-17 00:27:44,764 | train_utils.py:97 | Epoch 19 [Train]: loss 0.006324472756529142, mse: 0.00634557381272316, rmse: 0.07965911004224915, mae 0.05197861045598984, r2: 0.885360598564148, nrmse: 0.34511598944664, sse: 2260.19189453125, sst: 19715.66796875
# INFO logger 2025-11-17 00:27:44,765 | train_utils.py:99 | Epoch 19 [Test]: loss 6.150391936469495e-06, mse: 0.0062036458402872086, rmse: 0.07876322644665598, mae 0.05063692480325699, r2: 0.9044173955917358, nrmse: 0.29556402564048767, sse: 546.7149047851562, sst: 5719.81591796875
# INFO logger 2025-11-17 00:27:44,765 | helpers.py:142 | EarlyStopping counter: 5 out of 10
# INFO logger 2025-11-17 00:28:10,655 | train_utils.py:97 | Epoch 20 [Train]: loss 0.006314883952633874, mse: 0.006339820567518473, rmse: 0.07962299019453159, mae 0.052232593297958374, r2: 0.8854645490646362, nrmse: 0.3449594974517822, sse: 2258.142578125, sst: 19715.66796875
# INFO logger 2025-11-17 00:28:10,656 | train_utils.py:99 | Epoch 20 [Test]: loss 6.159203714260273e-06, mse: 0.006212699692696333, rmse: 0.078820680615536, mae 0.0507722906768322, r2: 0.9042779207229614, nrmse: 0.29577964544296265, sse: 547.5128173828125, sst: 5719.81591796875
# INFO logger 2025-11-17 00:28:10,656 | helpers.py:142 | EarlyStopping counter: 6 out of 10
# INFO logger 2025-11-17 00:28:36,568 | train_utils.py:97 | Epoch 21 [Train]: loss 0.006269851986495456, mse: 0.0063249291852116585, rmse: 0.07952942339292834, mae 0.05192666873335838, r2: 0.8857336044311523, nrmse: 0.3445541262626648, sse: 2252.838623046875, sst: 19715.66796875
# INFO logger 2025-11-17 00:28:36,568 | train_utils.py:99 | Epoch 21 [Test]: loss 6.163733153750737e-06, mse: 0.006216348614543676, rmse: 0.0788438242004006, mae 0.05057285353541374, r2: 0.9042216539382935, nrmse: 0.2958664894104004, sse: 547.8343505859375, sst: 5719.81591796875
# INFO logger 2025-11-17 00:28:36,568 | helpers.py:142 | EarlyStopping counter: 7 out of 10
# INFO logger 2025-11-17 00:29:02,617 | train_utils.py:97 | Epoch 22 [Train]: loss 0.006244770174942397, mse: 0.00635601906105876, rmse: 0.07972464525514529, mae 0.05133412778377533, r2: 0.8851718902587891, nrmse: 0.3453999161720276, sse: 2263.912353515625, sst: 19715.66796875
# INFO logger 2025-11-17 00:29:02,617 | train_utils.py:99 | Epoch 22 [Test]: loss 6.218752854099746e-06, mse: 0.006273297127336264, rmse: 0.07920414842251802, mae 0.05016661435365677, r2: 0.9033442735671997, nrmse: 0.2972186207771301, sse: 552.8531494140625, sst: 5719.81591796875
# INFO logger 2025-11-17 00:29:02,617 | helpers.py:142 | EarlyStopping counter: 8 out of 10
# INFO logger 2025-11-17 00:29:29,947 | train_utils.py:97 | Epoch 23 [Train]: loss 0.006234336910359883, mse: 0.006319817155599594, rmse: 0.07949727766156268, mae 0.05173904821276665, r2: 0.8858259320259094, nrmse: 0.3444148600101471, sse: 2251.017822265625, sst: 19715.66796875
# INFO logger 2025-11-17 00:29:29,947 | train_utils.py:99 | Epoch 23 [Test]: loss 6.216094691041565e-06, mse: 0.006264787167310715, rmse: 0.07915040851006844, mae 0.05066468566656113, r2: 0.9034753441810608, nrmse: 0.297016978263855, sse: 552.1031494140625, sst: 5719.81591796875
# INFO logger 2025-11-17 00:29:29,948 | helpers.py:142 | EarlyStopping counter: 9 out of 10
# INFO logger 2025-11-17 00:29:56,433 | train_utils.py:97 | Epoch 24 [Train]: loss 0.006188703378416255, mse: 0.006223731674253941, rmse: 0.07889063109301345, mae 0.05092494562268257, r2: 0.8875617980957031, nrmse: 0.34178659319877625, sse: 2216.793701171875, sst: 19715.66796875
# INFO logger 2025-11-17 00:29:56,434 | train_utils.py:99 | Epoch 24 [Test]: loss 6.116996922430642e-06, mse: 0.006159587763249874, rmse: 0.0784830412461818, mae 0.049881625920534134, r2: 0.9050962328910828, nrmse: 0.2945125997066498, sse: 542.8321533203125, sst: 5719.81591796875
# INFO logger 2025-11-17 00:29:56,434 | helpers.py:142 | EarlyStopping counter: 10 out of 10
# INFO logger 2025-11-17 00:29:56,434 | train_utils.py:117 | Early Stopping
# INFO logger 2025-11-17 00:29:56,618 | train_utils.py:140 | Best Loss: 6.0912566688980366e-06, Best epoch: 24

# %% [markdown]
# ## the first time group count:

# %%
import pandas as pd

input_file = "./group_stage_results/best_n14_k4_r7_assignment.csv"  

df = pd.read_csv(input_file)

# count turbines in each cluster
cluster_counts = df["cluster"].value_counts().sort_index()
print("count of turbines in each cluster:")
for cluster_id, count in cluster_counts.items():
    print(f"Cluster {cluster_id}: {count} turbines")
# Out:
# count of turbines in each cluster:
# Cluster 0: 343 turbines
# Cluster 1: 51 turbines
# Cluster 2: 2 turbines
# Cluster 3: 4 turbines

# %%
# === input file ===
feature_file = "./selected feature statistics/features_in_group_stage_400_turbines.csv"
cluster_file = "./group_stage_results/first_group/best_n14_k4_r7_assignment.csv" 
output_file = "features_cluster_0_1st.csv"  
    
features_df = pd.read_csv(feature_file)
clusters_df = pd.read_csv(cluster_file)

# === merge data (by GSRN) ===
merged_df = pd.merge(features_df, clusters_df, on="GSRN", how="inner")

# === extract data where cluster is 0 or 1 ===
subset_df = merged_df[merged_df["cluster"].isin([0])]

subset_df.to_csv(output_file, index=False)

print(f"complete, total {len(subset_df)} rows of data, saved as: {output_file}")
# Out:
# complete, total 343 rows of data, saved as: features_cluster_0_1st.csv

# %%
input_file = "./group_stage_results/second_group/best_n6_k4_r4_assignment.csv"  

df = pd.read_csv(input_file)

# count turbines in each cluster
cluster_counts = df["cluster"].value_counts().sort_index()
print("count of turbines in each cluster for the second time group:")
for cluster_id, count in cluster_counts.items():
    print(f"Cluster {cluster_id}: {count} turbines")
# Out:
# count of turbines in each cluster for the second time group:
# Cluster 0: 243 turbines
# Cluster 1: 82 turbines
# Cluster 2: 6 turbines
# Cluster 3: 12 turbines

# %%
# === input file ===
feature_file = "./selected feature statistics/features_in_group_stage_400_turbines.csv"
cluster_file = "./group_stage_results/second_group/best_n11_k3_r5_assignment.csv"
output_file = "features_cluster_0_2th.csv"  
    
features_df = pd.read_csv(feature_file)
clusters_df = pd.read_csv(cluster_file)

# === merge data (by GSRN) ===
merged_df = pd.merge(features_df, clusters_df, on="GSRN", how="inner")

# === extract data where cluster is 0 or 1 ===
subset_df = merged_df[merged_df["cluster"].isin([0])]

subset_df.to_csv(output_file, index=False)

print(f"complete, total {len(subset_df)} rows of data, saved as: {output_file}")
# Out:
# complete, total 328 rows of data, saved as: features_cluster_0_2th.csv

# %%
input_file = "./group_stage_results/third_group/best_n14_k3_r9_assignment.csv"  

df = pd.read_csv(input_file)

# count turbines in each cluster
cluster_counts = df["cluster"].value_counts().sort_index()
print("count of turbines in each cluster for the third time group:")
for cluster_id, count in cluster_counts.items():
    print(f"Cluster {cluster_id}: {count} turbines")
# Out:
# count of turbines in each cluster for the third time group:
# Cluster 0: 116 turbines
# Cluster 1: 123 turbines
# Cluster 2: 4 turbines
